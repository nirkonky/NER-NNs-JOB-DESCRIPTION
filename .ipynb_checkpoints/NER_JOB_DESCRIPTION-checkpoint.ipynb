# %% [markdown]
# ## Development of a Benchmark Corpus to Support Entity Recognition in Job Descriptions
#
# Detecting and extracting entities is an important task in many real-world information extraction applications such as text classification,Search algorithms and content recommendations.
# Recruiting, companies today benefit from automated systems to acquire up-to-date information about job roles and detailed candidate profiles in terms of skills, qualifications and experience.
# However, the development of entity recognition (ER) to perform these tasks suffers severely due to the lack of publicly available datasets.
# Most of the available datasets consist of general news articles (newspapers, etc.).
#
# To develop better job matching tools, we need to address these issues.
# First we establish a definition of the relevant factors.
# Which are: skills, education, experience.
# We used this data set: train_rav_1 (https://www.kaggle.com/datasets/airiddha/trainrev1) which shows UK job descriptions, which is publicly available
# Build our data set above the data set defined above according to the three labels: skills, education, experience.
# Initially, we used text entity extraction tools to independently classify these three labels.
# Next, we present a benchmark between model x and model y.
#
# In addition, the data set created is publicly available, and can be used for other models.
# The source code can be found at (link to source code).

# %% [markdown]
# ### Instructions before starting

# %%
##Before we start
#As you can see, the models were taken from a github repo with minor tuning done to make the model work. Every computer and its individual case. I run with a macbook m1, so small adjustments were needed for the python and the model to run smoothly. Everything is listed below.

#Uncomment the 2 cp commands! and follow the instrucations!

#Replace <<Downloaded_glove.6b.100d.txt_diretory>> with your dowloaded glove embeddings directory.
#!cp -r <<Downloaded_glove.6b.100d.txt_diretory>> /embedding/glove.6B.100d.txt

#Replace <<Downloaded_trainrev1_dataset>> with your dowloaded dataset Train_rev1_2.csv
##Download dataset https://www.kaggle.com/datasets/airiddha/trainrev1 
#!cp -Rf <<Downloaded_trainrev1_dataset>> dataset/Train_rev1_2.csv ##Paste the dataset under directory: dataset/Train_rev1_2.csv

# %% [markdown]
# ## Dataset creation

# %% [markdown]
# ### First we need to understand how to extract experience, qualification/education & skills from the dataset.
# So, we need to create an extractors for all of the 3 labels we want to run on.
# ###### NOTE - We run this code already all night to get better IOB result file, SO take the sample i created already that called dataset/sample_dataset.conll

# %% [markdown]
# ### Skills
# We used ***SkillNer*** description can be found here: https://github.com/AnasAito/SkillNER
#
# ***SkillNer*** is an NLP module to automatically Extract skills and certifications from unstructured job postings, texts, and applicant's resumes.
# Skillner uses EMSI databse (an open source skill database) as a knowldge base linker to prevent skill duplications.

# %%
import os
from typing import List

os.environ["PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION"] = "python"
import spacy
from skillNer.general_params import SKILL_DB
from skillNer.skill_extractor_class import SkillExtractor
from spacy.matcher import PhraseMatcher

nlp = spacy.load("en_core_web_lg")
skill_extractor = SkillExtractor(nlp, SKILL_DB, PhraseMatcher)

def extract_skills(job_description: str) -> List[str]:
    try:
        annotations = skill_extractor.annotate(job_description)
        full_matches = [x['doc_node_value'] for x in annotations['results']['full_matches']]
        ngram_scored = [x['doc_node_value'] for x in annotations['results']['ngram_scored']]
        return full_matches + ngram_scored
    except Exception as e:
        print(f"Exception {e} on {job_description}, moving forward")
        return []
# Out:
# /Library/Python/3.8/site-packages/spacy/util.py:865: UserWarning: [W095] Model 'en_core_web_lg' (3.5.0) was trained with spaCy v3.5 and may not be 100% compatible with the current version (3.4.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# loading full_matcher ...
# loading abv_matcher ...
# loading full_uni_matcher ...
# loading low_form_matcher ...
# loading token_matcher ...

# %% [markdown]
# ### Education
#
# We used an regex matching to find any case of education.
# We listed the all options of education from job descriptions.
#
# ***NOTE - This is not the best practice, the best practice for now, is to build an education extraction via machine learning from text. Still in machine learning, there can be a problem that given a new education, he could not recognize it.
# Therefore it must be a contemporary skilled model***

# %%
import os

os.environ["PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION"] = "python"
import spacy
import re
from nltk.corpus import stopwords

# load pre-trained model
nlp = spacy.load('en_core_web_sm')

# Grad all general stop words
STOPWORDS = set(stopwords.words('english'))

# Education Degrees
EDUCATION = [
            'BE','B.E.', 'B.E', 'BS', 'B.S','C.A.','c.a.','B.Com','B. Com','M. Com', 'M.Com','M. Com .',
            'ME', 'M.E', 'M.E.', 'MS', 'M.S',
            'BTECH', 'B.TECH', 'M.TECH', 'MTECH',
            'PHD', 'phd', 'ph.d', 'Ph.D.','MBA','mba','graduate', 'post-graduate','5 year integrated masters','masters',
            'SSC', 'HSC', 'CBSE', 'ICSE', 'X', 'XII',
            'Hospital','University','Institute','School','School','Academy', 'Bachelor', 'High School', 'College', ''
        ]

def extract_education(job_description: str):
    nlp_text = nlp(job_description)
    # Sentence Tokenizer
    nlp_text = [sent.text.strip() for sent in nlp_text.sents]
    edu = []
    for index, text in enumerate(nlp_text):
        for tex in text.split():
            tex = re.sub(r'[?|$|.|!|,]', r'', tex)
            if tex.upper() in EDUCATION and tex not in STOPWORDS:
                edu.append(tex)
    return edu
# Out:
# /Library/Python/3.8/site-packages/spacy/util.py:865: UserWarning: [W095] Model 'en_core_web_sm' (3.5.0) was trained with spaCy v3.5 and may not be 100% compatible with the current version (3.4.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %% [markdown]
# ### Experience
#
# We used Regex to match experience  to find any case in text that includes exerience(etc: years).

# %%
import re

rx = re.compile(r"(\d+(?:-\d+)?\+?)\s*(years?)", re.I)

def extract_experience(job_description: str):
    exp_temp = rx.search(string=job_description)
    if exp_temp:
        list_return = []
        list_return = list_return.append(' '.join(exp_temp.groups()))
        return list_return

# %% [markdown]
# ### Dataset generation
#
# Now that we have all the extractors, we can run on the dataset file to create our train dataset in IOB format.

# %%
import csv
from typing import List

import nltk

pos_chunk_mapping = {
    'NN': 'B-NP',
    'NNS': 'B-NP',
    'NNP': 'B-NP',
    'NNPS': 'B-NP',
    'VB': 'B-VP',
    'VBD': 'B-VP',
    'VBG': 'B-VP',
    'VBN': 'B-VP',
    'VBP': 'B-VP',
    'VBZ': 'B-VP',
    'IN': 'B-PP',
    'TO': 'B-VP',
    'JJ': 'B-ADJP',
    'JJR': 'B-ADJP',
    'JJS': 'B-ADJP',
    'RB': 'B-ADVP',
    'RBR': 'B-ADVP',
    'RBS': 'B-ADVP',
    'DT': 'B-NP',
    'CD': 'B-NP',
    'PRP': 'B-NP',
    'PRP$': 'B-NP',
    'POS': 'B-NP',
    'EX': 'B-NP',
    'WDT': 'B-NP',
    'WP': 'B-NP',
    'WP$': 'B-NP',
    'WRB': 'B-ADVP',
    'MD': 'B-VP',
    'RP': 'B-PRT',
    'CC': 'B-CONJP',
    'PDT': 'B-ADJP',
    'FW': 'B-ADJP',
    'UH': 'B-INTJ',
    'SYM': 'B-SYM',
    'LS': 'B-LST',
    'ADD': 'B-NP',
    'GW': 'B-NP',
    'AFX': 'B-NP',
    'HYPH': 'B-NP',
    'NFP': 'B-NP',
    'XX': 'B-NP',
    'BES': 'B-VP',
    'HVS': 'B-VP',
    'XX': 'B-NP',
    'I-NP': 'I-NP',
    'I-VP': 'I-VP',
    'I-PP': 'I-PP',
    'I-ADJP': 'I-ADJP',
    'I-ADVP': 'I-ADVP',
    'I-PRT': 'I-PRT',
    'I-CONJP': 'I-CONJP',
    'I-INTJ': 'I-INTJ',
    'I-SYM': 'I-SYM',
    'I-LST': 'I-LST',
    'O': 'O'
}


dataset = "dataset/Train_rev1_2.csv"
MAX_SIZE = 2

def extract_full_item(token_to_find: str, tokens: List[str], items: List[str])-> str:
    token_to_find_index = tokens.index(token_to_find)
    tokens = tokens[token_to_find_index:token_to_find_index + MAX_SIZE]
    for (idx,token) in enumerate(tokens):
        for item in items:
            splitted_item = item.split(" ")
            if token == splitted_item[0]:
                if len(splitted_item) == 1:
                    return item
                else:
                    next_element = idx + 1
                    for x in range(1, len(splitted_item)):
                        if len(tokens) <= next_element:
                            break
                        else:
                            next_token = tokens[next_element]
                            if next_token != splitted_item[x]:
                                break
                            else:
                                if len(splitted_item) == x + 1:
                                    return item
                                else:
                                    next_element += 1
    return ""

def append_to_coll_data(extracted_item, token, pos_tag, chunk_tag, label):
    conll_data = []
    extracted_item_splitted = extracted_item.split(" ")
    for (kdx, extracted_item_chunk) in enumerate(extracted_item_splitted):
        if len(token) >= 1:
            if kdx == 0:
                conll_data.append(f"{extracted_item_chunk}\t{pos_tag[1]}\t{chunk_tag}\tB-{label}")
            else:
                conll_data.append(f"{extracted_item_chunk}\t{pos_tag[1]}\t{chunk_tag}\tI-{label}")
    return conll_data

def handle_token_labels(exp_label: str,
                        skill_label: str,
                        edu_label: str,
                        tokens: List[str],
                        token: str,
                        pos_tag: str,
                        chunk_tag: str,
                        skills_items: List[str],
                        edu_items: List[str],
                        exp_items: List[str]):
        conll_data = []
        extracted_skills_item = extract_full_item(token, tokens, skills_items)
        extracted_edus_item = extract_full_item(token, tokens, edu_items)
        extracted_exps_item = extract_full_item(token, tokens, exp_items)
        if extracted_skills_item == "" and extracted_edus_item == "" and extracted_exps_item == "":
            conll_data += [f"{token}\t{pos_tag[1]}\t{chunk_tag}\tO"]
        elif extracted_exps_item != "":
            conll_data += append_to_coll_data(extracted_exps_item, token, pos_tag, chunk_tag, exp_label)
        elif extracted_skills_item != "":
            conll_data += append_to_coll_data(extracted_skills_item, token, pos_tag, chunk_tag, skill_label)
        elif extracted_edus_item != "":
            conll_data += append_to_coll_data(extracted_edus_item, token, pos_tag, chunk_tag, edu_label)
        return conll_data

def loop_on_chunks(chunk: List[List[str]]) -> List[str]:
    global conll_data_string
    conll_data = []
    # Create a chunk parser using a predefined chunk grammar

    # Perform chunking
    for (idx, row) in enumerate(chunk):
        print(f"on line: {idx}")
        full_description_lower = row[2].lower()
        full_description_lower_splitted: List[str] = full_description_lower.split(".") # Full description
        lines_tokens = [nltk.word_tokenize(line) for line in full_description_lower_splitted]
        for (line, tokens) in zip(full_description_lower_splitted, lines_tokens):
            skills: line[str] = extract_skills(job_description=line) or []
            educations: list[str] = extract_education(job_description=line) or []
            experiences: list[str] = extract_experience(job_description=line) or []
            pos_tags = nltk.pos_tag(tokens)
            jdx = 0
            for (token, pos_tag) in zip(tokens, pos_tags):
                try:
                    chunk_tag = pos_chunk_mapping[pos_tag[1]]
                except Exception as error:
                    chunk_tag = '0'

                token = tokens[jdx]
                pos_tag = pos_tags[jdx]
                conll_data_result = handle_token_labels(exp_label="EXP",
                                                        skill_label="SKILL",
                                                        edu_label="EDU",
                                                        tokens=tokens,
                                                        token=token,
                                                        pos_tag=pos_tag,
                                                        chunk_tag=chunk_tag,
                                                        skills_items=skills,
                                                        edu_items=educations,
                                                        exp_items=experiences)
                conll_data += ['\n']
                conll_data += conll_data_result
                jdx += len(conll_data_result)
                if jdx >= len(tokens):
                    break
            conll_data += ['\n']
    return conll_data

def generate_rows(output_path):
    N = 20
    with open(dataset, 'r') as file:
        csvreader = list(csv.reader(file))
        csvreader.pop(0)
        chunks: List[List[List[str]]] = [csvreader[x:x + N] for x in range(0, len(csvreader) - 1, N)]
        with open(output_path, 'w') as output_file:
            output_file.write('-DOCSTART- -X- -X- O')
            output_file.write('\n')
        with open(output_path, 'a') as output_file:
            for (idx, chunk) in enumerate(chunks):
                lines = loop_on_chunks(chunk=chunk)
                output_file.writelines(lines)
                print(f"Finished chunk number: {idx}/{ len(chunks)}")

generate_rows('dataset/dataset_2.conll')
# Out:
# on line: 0
# /Library/Python/3.8/site-packages/skillNer/utils.py:99: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   vec_similarity = token1.similarity(token2)
# on line: 1
# on line: 2
# on line: 3
# on line: 4
# on line: 5
# on line: 6
# on line: 7
# on line: 8
# on line: 9
# on line: 10
# on line: 11
# on line: 12
# on line: 13
# on line: 14
# on line: 15
# on line: 16
# on line: 17
# on line: 18
# on line: 19
# Finished chunk number: 0/12239
# on line: 0
# on line: 1
# on line: 2
# on line: 3
# on line: 4
# on line: 5
# on line: 6
# on line: 7
# on line: 8
# on line: 9
# on line: 10
# on line: 11
# on line: 12
# on line: 13
# on line: 14
# on line: 15
# on line: 16
# on line: 17
# on line: 18
# on line: 19
# Finished chunk number: 1/12239
# on line: 0
# on line: 1
# on line: 2
# on line: 3
# on line: 4
# on line: 5
# on line: 6
# on line: 7
# on line: 8
# on line: 9
# on line: 10
# on line: 11
# on line: 12
# on line: 13
# on line: 14
# on line: 15
# on line: 16
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 187
#     184                 output_file.writelines(lines)
#     185                 print(f"Finished chunk number: {idx}/{ len(chunks)}")
# --> 187 generate_rows('dataset_2.conll')
#
# Cell In[13], line 183, in generate_rows(output_path)
#     181 with open(output_path, 'a') as output_file:
#     182     for (idx, chunk) in enumerate(chunks):
# --> 183         lines = loop_on_chunks(chunk=chunk)
#     184         output_file.writelines(lines)
#     185         print(f"Finished chunk number: {idx}/{ len(chunks)}")
#
# Cell In[13], line 141, in loop_on_chunks(chunk)
#     139 lines_tokens = [nltk.word_tokenize(line) for line in full_description_lower_splitted]
#     140 for (line, tokens) in zip(full_description_lower_splitted, lines_tokens):
# --> 141     skills: line[str] = extract_skills(job_description=line) or []
#     142     educations: list[str] = extract_education(job_description=line) or []
#     143     experiences: list[str] = extract_experience(job_description=line) or []
#
# Cell In[3], line 15, in extract_skills(job_description)
#      13 def extract_skills(job_description: str) -> List[str]:
#      14     try:
# ---> 15         annotations = skill_extractor.annotate(job_description)
#      16         full_matches = [x['doc_node_value'] for x in annotations['results']['full_matches']]
#      17         ngram_scored = [x['doc_node_value'] for x in annotations['results']['ngram_scored']]
#
# File /Library/Python/3.8/site-packages/skillNer/skill_extractor_class.py:126, in SkillExtractor.annotate(self, text, tresh)
#     121 # tests
#     123 skills_abv, text_obj = self.skill_getters.get_abv_match_skills(
#     124     text_obj, self.matchers['abv_matcher'])
# --> 126 skills_uni_full, text_obj = self.skill_getters.get_full_uni_match_skills(
#     127     text_obj, self.matchers['full_uni_matcher'])
#     129 skills_low_form, text_obj = self.skill_getters.get_low_match_skills(
#     130     text_obj, self.matchers['low_form_matcher'])
#     132 skills_on_token = self.skill_getters.get_token_match_skills(
#     133     text_obj, self.matchers['token_matcher'])
#
# File /Library/Python/3.8/site-packages/skillNer/matcher_class.py:284, in SkillsGetter.get_full_uni_match_skills(self, text_obj, matcher)
#     276 def get_full_uni_match_skills(
#     277     self,
#     278     text_obj: Text,
#     279     matcher
#     280 ):
#     282     skills = []
# --> 284     doc = self.nlp(text_obj.transformed_text)
#     285     for match_id, start, end in matcher(doc):
#     286         id_ = matcher.vocab.strings[match_id]
#
# File /Library/Python/3.8/site-packages/spacy/language.py:1020, in Language.__call__(self, text, disable, component_cfg)
#    1018     error_handler = proc.get_error_handler()
#    1019 try:
# -> 1020     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1021 except KeyError as e:
#    1022     # This typically happens if a component is not initialized
#    1023     raise ValueError(Errors.E109.format(name=name)) from e
#
# File /Library/Python/3.8/site-packages/spacy/pipeline/trainable_pipe.pyx:52, in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# File /Library/Python/3.8/site-packages/spacy/pipeline/tok2vec.py:125, in Tok2Vec.predict(self, docs)
#     123     width = self.model.get_dim("nO")
#     124     return [self.model.ops.alloc((0, width)) for doc in docs]
# --> 125 tokvecs = self.model.predict(docs)
#     126 batch_id = Tok2VecListener.get_batch_id(docs)
#     127 for listener in self.listeners:
#
# File /Library/Python/3.8/site-packages/thinc/model.py:315, in Model.predict(self, X)
#     311 def predict(self, X: InT) -> OutT:
#     312     """Call the model's `forward` function with `is_train=False`, and return
#     313     only the output, instead of the `(output, callback)` tuple.
#     314     """
# --> 315     return self._func(self, X, is_train=False)[0]
#
# File /Library/Python/3.8/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File /Library/Python/3.8/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File /Library/Python/3.8/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File /Library/Python/3.8/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File /Library/Python/3.8/site-packages/thinc/layers/with_array.py:37, in forward(model, Xseq, is_train)
#      33 def forward(
#      34     model: Model[SeqT, SeqT], Xseq: SeqT, is_train: bool
#      35 ) -> Tuple[SeqT, Callable]:
#      36     if isinstance(Xseq, Ragged):
# ---> 37         return cast(Tuple[SeqT, Callable], _ragged_forward(model, Xseq, is_train))
#      38     elif isinstance(Xseq, Padded):
#      39         return cast(Tuple[SeqT, Callable], _padded_forward(model, Xseq, is_train))
#
# File /Library/Python/3.8/site-packages/thinc/layers/with_array.py:92, in _ragged_forward(model, Xr, is_train)
#      88 def _ragged_forward(
#      89     model: Model[SeqT, SeqT], Xr: Ragged, is_train: bool
#      90 ) -> Tuple[Ragged, Callable]:
#      91     layer: Model[ArrayXd, ArrayXd] = model.layers[0]
# ---> 92     Y, get_dX = layer(Xr.dataXd, is_train)
#      94     def backprop(dYr: Ragged) -> Ragged:
#      95         return Ragged(get_dX(dYr.dataXd), dYr.lengths)
#
# File /Library/Python/3.8/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File /Library/Python/3.8/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File /Library/Python/3.8/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File /Library/Python/3.8/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File /Library/Python/3.8/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File /Library/Python/3.8/site-packages/thinc/layers/maxout.py:53, in forward(model, X, is_train)
#      51 W = model.get_param("W")
#      52 W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 53 Y = model.ops.gemm(X, W, trans2=True)
#      54 Y += model.ops.reshape1f(b, nO * nP)
#      55 Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Seperate Dataset To Dev,Train,Test
#
# So, after we created this sample_dataset.conll
# We need to seperate it to train,dev,test

# %%
def split_dataset(dataset_filepath, train_filepath, dev_filepath, test_filepath):
    with open(dataset_filepath, 'r') as file:
        dataset = file.readlines()

        train_ratio = 0.7
        dev_ratio = 0.15
        test_ratio = 0.15

        total_samples = len(dataset)
        train_end = int(total_samples * train_ratio)
        dev_end = int(total_samples * (train_ratio + dev_ratio))

        train_set = dataset[:train_end]
        dev_set = dataset[train_end:dev_end]
        test_set = dataset[dev_end:]

        write_to_file(train_filepath, train_set)
        write_to_file(dev_filepath, dev_set)
        write_to_file(test_filepath, test_set)
        
def write_to_file(file_name, data):
    with open(file_name, 'w') as file:
        file.write("-DOCSTART- -X- -X- O")
        file.write("\n")
        file.writelines(data)
        
dataset_filepath = "dataset/sample_dataset.conll"
train_filepath = "dataset/split_dataset/conllpp_train.txt"
dev_filepath = "dataset/split_dataset/conllpp_dev.txt"
test_filepath = "dataset/split_dataset/conllpp_test.txt"
split_dataset(dataset_filepath, train_filepath, dev_filepath, test_filepath)
print("Data has been splitted!")
# Out:
# Data has been splitted!

# %% [markdown]
# ## Models
#
# ### LM-LSTM-CRF
# Github link: https://github.com/LiyuanLucasLiu/LM-LSTM-CRF/blob/master
# Readme: https://github.com/LiyuanLucasLiu/LM-LSTM-CRF/blob/master/README.md
#
# #### NLP Progress
# - LM-LSTM-CRF (Liu et al., 2018)
# - F1: 91.24
#
# #### Description
# ![image.png](attachment:image.png)
# As visualized above, they use conditional random field (CRF) to capture label dependencies, and adopt a hierarchical LSTM to leverage both char-level and word-level inputs. The char-level structure is further guided by a language model, while pre-trained word embeddings are leveraged in word-level. The language model and the sequence labeling model are trained at the same time, and both make predictions at word-level. Highway networks are used to transform the output of char-level LSTM into different semantic spaces, and thus mediating these two tasks and allowing language model to empower sequence labeling.
#
# ***NOTE - please follow those instructions in the readme file for specific versions of libraries.***
#
# ***NOTE - Download embeddings glove.6B.100d.txt and paste it under ./embedding/glove.6B.100d.txt
# Run this code to run the model and get the F1 Score.***

# %%
##Run the model
##NOTE - in case of you get an error in set_device function from torch 
##       1.Please remove the set_device from the code in the repo.
##         Because, we do not use GPU here, the dataset is small.
##.      2.Remove .cuda() from every element uses it. (e.g. model.cuda() -> model)
# !python3 models/LM-LSTM-CRF/train_wc.py --train_file dataset/split_dataset/conllpp_train.txt --dev_file dataset/split_dataset/conllpp_dev.txt --test_file dataset/split_dataset/conllpp_test.txt --checkpoint ./checkpoint/ner_ --caseless --fine_tune --high_way --co_train --least_iters 100 --emb_file embeddings/glove.6B.100d.txt --checkpoint models/LM-LSTM-CRF/checkpoint
# Out:
# setting:
# Namespace(batch_size=10, caseless=True, char_dim=30, char_hidden=300, char_layers=1, checkpoint='models/LM-LSTM-CRF/checkpoint', clip_grad=5.0, co_train=True, dev_file='dataset/split_dataset/conllpp_dev.txt', drop_out=0.55, emb_file='embeddings/glove.6B.100d.txt', epoch=200, eva_matrix='fa', fine_tune=False, gpu=0, high_way=True, highway_layers=1, lambda0=1, least_iters=100, load_check_point='', load_opt=False, lr=0.015, lr_decay=0.05, mini_count=5, momentum=0.9, patience=15, rand_embedding=False, shrink_embedding=False, small_crf=True, start_epoch=0, test_file='dataset/split_dataset/conllpp_test.txt', train_file='dataset/split_dataset/conllpp_train.txt', unk='unk', update='sgd', word_dim=100, word_hidden=300, word_layers=1)
# loading corpus
# constructing coding table
# feature size: '3394'
# loading embedding
# embedding size: '400133'
# constructing dataset
# building model
# /Users/nir.konky/Library/Python/3.8/lib/python/site-packages/torch/nn/modules/rnn.py:62: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.55 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
#  - Tot it 1501 (epoch 0): 0it [00:00, ?it/s]/Users/nir.konky/Library/Python/3.8/lib/python/site-packages/torch/nn/functional.py:1805: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# /Users/nir.konky/nir/nlp/NER-Course-Nir/models/LM-LSTM-CRF/model/crf.py:287: UserWarning: masked_select received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/TensorAdvancedIndexing.cpp:1187.)
#   tg_energy = tg_energy.masked_select(mask).sum()
# /Users/nir.konky/nir/nlp/NER-Course-Nir/models/LM-LSTM-CRF/model/crf.py:307: UserWarning: masked_select received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/TensorAdvancedIndexing.cpp:1187.)
#   partition.masked_scatter_(mask_idx, cur_partition.masked_select(mask_idx))  #0 for partition, 1 for cur_partition
# /Users/nir.konky/nir/nlp/NER-Course-Nir/models/LM-LSTM-CRF/model/crf.py:307: UserWarning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/TensorAdvancedIndexing.cpp:1401.)
#   partition.masked_scatter_(mask_idx, cur_partition.masked_select(mask_idx))  #0 for partition, 1 for cur_partition
# /Users/nir.konky/Library/Python/3.8/lib/python/site-packages/torch/autograd/__init__.py:147: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/TensorAdvancedIndexing.cpp:1104.)
#   Variable._execution_engine.run_backward(
# /Users/nir.konky/Library/Python/3.8/lib/python/site-packages/torch/autograd/__init__.py:147: UserWarning: masked_select received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/TensorAdvancedIndexing.cpp:1187.)
#   Variable._execution_engine.run_backward(
# /Users/nir.konky/Library/Python/3.8/lib/python/site-packages/torch/autograd/__init__.py:147: UserWarning: masked_scatter_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/TensorAdvancedIndexing.cpp:1401.)
#   Variable._execution_engine.run_backward(
# /Users/nir.konky/nir/nlp/NER-Course-Nir/models/LM-LSTM-CRF/model/crf.py:372: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/TensorAdvancedIndexing.cpp:1104.)
#   cur_bp.masked_fill_(mask[idx].view(bat_size, 1).expand(bat_size, self.tagset_size), self.end_tag)
# DEV : total : dev_f1: 0.8075 dev_rec: 0.7508 dev_pre: 0.8735 dev_acc: 0.9612 |
#
# DEV : O : dev_f1: 0.9809 dev_rec: 0.9902 dev_pre: 0.9718 dev_acc: 0.0000 | {'B-SKILL': 584, 'I-SKILL': 77}
#
# DEV : B-SKILL : dev_f1: 0.8543 dev_rec: 0.8352 dev_pre: 0.8742 dev_acc: 0.0000 | {'O': 1071, 'I-SKILL': 92}
#
# DEV : I-SKILL : dev_f1: 0.4247 dev_rec: 0.2980 dev_pre: 0.7388 dev_acc: 0.0000 | {'B-SKILL': 263, 'O': 863}
#
# DEV : B-EDU : dev_f1: 0.2000 dev_rec: 0.1111 dev_pre: 1.0000 dev_acc: 0.0000 | {'O': 7, 'B-SKILL': 1}
#
# TEST : total : test_f1: 0.7883 test_rec: 0.7369 test_pre: 0.8475 test_acc: 0.9540 |
#
# TEST : O : test_f1: 0.9774 test_rec: 0.9869 test_pre: 0.9681 test_acc: 0.0000 | {'B-SKILL': 812, 'I-SKILL': 68}
#
# TEST : B-SKILL : test_f1: 0.8347 test_rec: 0.8282 test_pre: 0.8414 test_acc: 0.0000 | {'O': 1176, 'I-SKILL': 97}
#
# TEST : I-SKILL : test_f1: 0.3713 test_rec: 0.2492 test_pre: 0.7286 test_acc: 0.0000 | {'O': 991, 'B-SKILL': 344}
#
# TEST : B-EDU : test_f1: 0.1000 test_rec: 0.0526 test_pre: 1.0000 test_acc: 0.0000 | {'O': 17, 'B-SKILL': 1}
#
# (loss: 4.6192, epoch: 0, dev F1 = 0.8075, dev acc = 0.9612, F1 on test = 0.7883, acc on test= 0.9540), saving...
# epoch: 0	 in 200 take: 1736.2277131080627 s
# DEV : total : dev_f1: 0.8544 dev_rec: 0.8085 dev_pre: 0.9057 dev_acc: 0.9704 |
#
# DEV : O : dev_f1: 0.9855 dev_rec: 0.9929 dev_pre: 0.9782 dev_acc: 0.0000 | {'I-SKILL': 113, 'B-SKILL': 368}
#
# DEV : B-SKILL : dev_f1: 0.9063 dev_rec: 0.8956 dev_pre: 0.9173 dev_acc: 0.0000 | {'O': 656, 'I-SKILL': 81}
#
# DEV : I-SKILL : dev_f1: 0.4827 dev_rec: 0.3566 dev_pre: 0.7467 dev_acc: 0.0000 | {'B-SKILL': 197, 'O': 835}
#
# DEV : B-EDU : dev_f1: 0.2000 dev_rec: 0.1111 dev_pre: 1.0000 dev_acc: 0.0000 | {'B-SKILL': 5, 'O': 3}
#
# TEST : total : test_f1: 0.8326 test_rec: 0.7874 test_pre: 0.8832 test_acc: 0.9633 |
#
# TEST : O : test_f1: 0.9821 test_rec: 0.9902 test_pre: 0.9741 test_acc: 0.0000 | {'B-SKILL': 553, 'I-SKILL': 102}
#
# TEST : B-SKILL : test_f1: 0.8825 test_rec: 0.8791 test_pre: 0.8859 test_acc: 0.0000 | {'O': 800, 'I-SKILL': 96}
#
# TEST : I-SKILL : test_f1: 0.4330 test_rec: 0.3071 test_pre: 0.7339 test_acc: 0.0000 | {'O': 951, 'B-SKILL': 281}
#
# TEST : B-EDU : test_f1: 0.1000 test_rec: 0.0526 test_pre: 1.0000 test_acc: 0.0000 | {'O': 13, 'B-SKILL': 5}
#
# (loss: 2.8502, epoch: 1, dev F1 = 0.8544, dev acc = 0.9704, F1 on test = 0.8326, acc on test= 0.9633), saving...
# epoch: 1	 in 200 take: 5383.1402270793915 s
# DEV : total : dev_f1: 0.8586 dev_rec: 0.8046 dev_pre: 0.9203 dev_acc: 0.9723 |
#
# DEV : O : dev_f1: 0.9867 dev_rec: 0.9946 dev_pre: 0.9788 dev_acc: 0.0000 | {'I-SKILL': 87, 'B-SKILL': 276}
#
# DEV : B-SKILL : dev_f1: 0.9155 dev_rec: 0.8942 dev_pre: 0.9379 dev_acc: 0.0000 | {'O': 596, 'I-SKILL': 151}
#
# DEV : I-SKILL : dev_f1: 0.4982 dev_rec: 0.3809 dev_pre: 0.7197 dev_acc: 0.0000 | {'B-SKILL': 142, 'O': 851}
#
# DEV : B-EDU : dev_f1: 0.2000 dev_rec: 0.1111 dev_pre: 1.0000 dev_acc: 0.0000 | {'O': 8}
#
# TEST : total : test_f1: 0.8500 test_rec: 0.7972 test_pre: 0.9102 test_acc: 0.9676 |
#
# TEST : O : test_f1: 0.9845 test_rec: 0.9932 test_pre: 0.9759 test_acc: 0.0000 | {'B-SKILL': 382, 'I-SKILL': 72}
#
# TEST : B-SKILL : test_f1: 0.9029 test_rec: 0.8911 test_pre: 0.9150 test_acc: 0.0000 | {'O': 667, 'I-SKILL': 140}
#
# TEST : I-SKILL : test_f1: 0.4544 test_rec: 0.3290 test_pre: 0.7340 test_acc: 0.0000 | {'O': 965, 'B-SKILL': 228}
#
# TEST : B-EDU : test_f1: 0.1000 test_rec: 0.0526 test_pre: 1.0000 test_acc: 0.0000 | {'O': 15, 'B-SKILL': 3}
#
# (loss: 2.3695, epoch: 2, dev F1 = 0.8586, dev acc = 0.9723, F1 on test = 0.8500, acc on test= 0.9676), saving...
# epoch: 2	 in 200 take: 7407.2884957790375 s
# DEV : total : dev_f1: 0.8705 dev_rec: 0.8187 dev_pre: 0.9294 dev_acc: 0.9738 |
#
# DEV : O : dev_f1: 0.9872 dev_rec: 0.9953 dev_pre: 0.9792 dev_acc: 0.0000 | {'I-SKILL': 147, 'B-SKILL': 173}
#
# DEV : B-SKILL : dev_f1: 0.9241 dev_rec: 0.8973 dev_pre: 0.9526 dev_acc: 0.0000 | {'O': 618, 'I-SKILL': 107}
#
# DEV : I-SKILL : dev_f1: 0.5248 dev_rec: 0.4121 dev_pre: 0.7224 dev_acc: 0.0000 | {'B-SKILL': 142, 'O': 801}
#
# DEV : B-EDU : dev_f1: 0.2000 dev_rec: 0.1111 dev_pre: 1.0000 dev_acc: 0.0000 | {'O': 8}
# TEST : total : test_f1: 0.8533 test_rec: 0.7958 test_pre: 0.9199 test_acc: 0.9686 |
#
# TEST : O : test_f1: 0.9848 test_rec: 0.9946 test_pre: 0.9752 test_acc: 0.0000 | {'I-SKILL': 128, 'B-SKILL': 234}
#
# TEST : B-SKILL : test_f1: 0.9079 test_rec: 0.8807 test_pre: 0.9368 test_acc: 0.0000 | {'O': 751, 'I-SKILL': 133}
#
# TEST : I-SKILL : test_f1: 0.4795 test_rec: 0.3616 test_pre: 0.7113 test_acc: 0.0000 | {'O': 930, 'B-SKILL': 205}
#
# TEST : B-EDU : test_f1: 0.1053 test_rec: 0.0556 test_pre: 1.0000 test_acc: 0.0000 | {'O': 16, 'B-SKILL': 1}
#
# (loss: 2.1198, epoch: 3, dev F1 = 0.8705, dev acc = 0.9738, F1 on test = 0.8533, acc on test= 0.9686), saving...
# epoch: 3	 in 200 take: 9412.377148866653 s
# DEV : total : dev_f1: 0.8737 dev_rec: 0.8210 dev_pre: 0.9336 dev_acc: 0.9749 |
#
# DEV : O : dev_f1: 0.9877 dev_rec: 0.9959 dev_pre: 0.9797 dev_acc: 0.0000 | {'I-SKILL': 114, 'B-SKILL': 165}
#
# DEV : B-SKILL : dev_f1: 0.9281 dev_rec: 0.9037 dev_pre: 0.9539 dev_acc: 0.0000 | {'O': 583, 'I-SKILL': 97}
#
# DEV : I-SKILL : dev_f1: 0.5316 dev_rec: 0.4096 dev_pre: 0.7569 dev_acc: 0.0000 | {'B-SKILL': 138, 'O': 809}
#
# DEV : B-EDU : dev_f1: 0.4000 dev_rec: 0.2500 dev_pre: 1.0000 dev_acc: 0.0000 | {'O': 1, 'B-SKILL': 5}
#
# TEST : total : test_f1: 0.8630 test_rec: 0.8076 test_pre: 0.9266 test_acc: 0.9707 |
#
# TEST : O : test_f1: 0.9859 test_rec: 0.9953 test_pre: 0.9766 test_acc: 0.0000 | {'I-SKILL': 97, 'B-SKILL': 219, 'B-EDU': 1}
#
# TEST : B-SKILL : test_f1: 0.9159 test_rec: 0.8924 test_pre: 0.9405 test_acc: 0.0000 | {'O': 674, 'I-SKILL': 123}
#
# TEST : I-SKILL : test_f1: 0.5022 test_rec: 0.3768 test_pre: 0.7528 test_acc: 0.0000 | {'O': 912, 'B-SKILL': 196}
#
# TEST : B-EDU : test_f1: 0.3478 test_rec: 0.2222 test_pre: 0.8000 test_acc: 0.0000 | {'O': 11, 'B-SKILL': 3}
#
# (loss: 1.9210, epoch: 4, dev F1 = 0.8737, dev acc = 0.9749, F1 on test = 0.8630, acc on test= 0.9707), saving...
# epoch: 4	 in 200 take: 11436.934074878693 s
# DEV : total : dev_f1: 0.8862 dev_rec: 0.8396 dev_pre: 0.9384 dev_acc: 0.9771 |
#
# DEV : O : dev_f1: 0.9888 dev_rec: 0.9958 dev_pre: 0.9819 dev_acc: 0.0000 | {'I-SKILL': 101, 'B-SKILL': 183, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9389 dev_rec: 0.9249 dev_pre: 0.9533 dev_acc: 0.0000 | {'O': 447, 'I-SKILL': 83}
#
# DEV : I-SKILL : dev_f1: 0.5481 dev_rec: 0.4208 dev_pre: 0.7858 dev_acc: 0.0000 | {'B-SKILL': 136, 'O': 793}
#
# DEV : B-EDU : dev_f1: 0.6154 dev_rec: 0.5000 dev_pre: 0.8000 dev_acc: 0.0000 | {'O': 3, 'B-SKILL': 1}
#
# TEST : total : test_f1: 0.8744 test_rec: 0.8255 test_pre: 0.9294 test_acc: 0.9727 |
#
# TEST : O : test_f1: 0.9868 test_rec: 0.9949 test_pre: 0.9788 test_acc: 0.0000 | {'I-SKILL': 96, 'B-SKILL': 248, 'B-EDU': 1}
#
# TEST : B-SKILL : test_f1: 0.9252 test_rec: 0.9135 test_pre: 0.9373 test_acc: 0.0000 | {'O': 552, 'I-SKILL': 89}
#
# TEST : I-SKILL : test_f1: 0.5235 test_rec: 0.3915 test_pre: 0.7900 test_acc: 0.0000 | {'O': 878, 'B-SKILL': 204}
#
# TEST : B-EDU : test_f1: 0.4167 test_rec: 0.2778 test_pre: 0.8333 test_acc: 0.0000 | {'O': 12, 'B-SKILL': 1}
#
# (loss: 1.8056, epoch: 5, dev F1 = 0.8862, dev acc = 0.9771, F1 on test = 0.8744, acc on test= 0.9727), saving...
# epoch: 5	 in 200 take: 13424.504661083221 s
# DEV : total : dev_f1: 0.8924 dev_rec: 0.8527 dev_pre: 0.9360 dev_acc: 0.9781 |
#
# DEV : O : dev_f1: 0.9892 dev_rec: 0.9952 dev_pre: 0.9833 dev_acc: 0.0000 | {'I-SKILL': 140, 'B-SKILL': 184, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9439 dev_rec: 0.9344 dev_pre: 0.9536 dev_acc: 0.0000 | {'O': 398, 'I-SKILL': 64, 'B-EDU': 1}
#
# DEV : I-SKILL : dev_f1: 0.5741 dev_rec: 0.4539 dev_pre: 0.7811 dev_acc: 0.0000 | {'B-SKILL': 136, 'O': 739, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.5333 dev_rec: 0.5000 dev_pre: 0.5714 dev_acc: 0.0000 | {'O': 3, 'B-SKILL': 1}
#
# TEST : total : test_f1: 0.8813 test_rec: 0.8370 test_pre: 0.9305 test_acc: 0.9741 |
#
# TEST : O : test_f1: 0.9875 test_rec: 0.9948 test_pre: 0.9802 test_acc: 0.0000 | {'I-SKILL': 102, 'B-SKILL': 243, 'B-EDU': 1}
#
# TEST : B-SKILL : test_f1: 0.9317 test_rec: 0.9251 test_pre: 0.9384 test_acc: 0.0000 | {'O': 484, 'I-SKILL': 71}
#
# TEST : I-SKILL : test_f1: 0.5391 test_rec: 0.4049 test_pre: 0.8063 test_acc: 0.0000 | {'O': 852, 'B-SKILL': 206}
#
# TEST : B-EDU : test_f1: 0.4167 test_rec: 0.2778 test_pre: 0.8333 test_acc: 0.0000 | {'O': 12, 'B-SKILL': 1}
#
# (loss: 1.6983, epoch: 6, dev F1 = 0.8924, dev acc = 0.9781, F1 on test = 0.8813, acc on test= 0.9741), saving...
# epoch: 6	 in 200 take: 15443.425065040588 s
# DEV : total : dev_f1: 0.8954 dev_rec: 0.8670 dev_pre: 0.9259 dev_acc: 0.9782 |
#
# DEV : O : dev_f1: 0.9895 dev_rec: 0.9938 dev_pre: 0.9851 dev_acc: 0.0000 | {'I-SKILL': 235, 'B-SKILL': 183, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9455 dev_rec: 0.9345 dev_pre: 0.9568 dev_acc: 0.0000 | {'O': 351, 'I-SKILL': 110, 'B-EDU': 1}
#
# DEV : I-SKILL : dev_f1: 0.5963 dev_rec: 0.5162 dev_pre: 0.7059 dev_acc: 0.0000 | {'B-SKILL': 114, 'O': 661, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.7059 dev_rec: 0.7500 dev_pre: 0.6667 dev_acc: 0.0000 | {'B-SKILL': 1, 'O': 1}
#
# TEST : total : test_f1: 0.8854 test_rec: 0.8532 test_pre: 0.9201 test_acc: 0.9748 |
#
# TEST : O : test_f1: 0.9879 test_rec: 0.9934 test_pre: 0.9825 test_acc: 0.0000 | {'I-SKILL': 175, 'B-SKILL': 267, 'B-EDU': 3}
#
# TEST : B-SKILL : test_f1: 0.9342 test_rec: 0.9281 test_pre: 0.9405 test_acc: 0.0000 | {'O': 409, 'I-SKILL': 124}
#
# TEST : I-SKILL : test_f1: 0.5745 test_rec: 0.4708 test_pre: 0.7368 test_acc: 0.0000 | {'O': 774, 'B-SKILL': 167}
#
# TEST : B-EDU : test_f1: 0.7273 test_rec: 0.6667 test_pre: 0.8000 test_acc: 0.0000 | {'O': 5, 'B-SKILL': 1}
#
# (loss: 1.6200, epoch: 7, dev F1 = 0.8954, dev acc = 0.9782, F1 on test = 0.8854, acc on test= 0.9748), saving...
# epoch: 7	 in 200 take: 17329.19913506508 s
# DEV : total : dev_f1: 0.8993 dev_rec: 0.8674 dev_pre: 0.9337 dev_acc: 0.9791 |
#
# DEV : O : dev_f1: 0.9898 dev_rec: 0.9947 dev_pre: 0.9850 dev_acc: 0.0000 | {'I-SKILL': 204, 'B-SKILL': 155}
#
# DEV : B-SKILL : dev_f1: 0.9486 dev_rec: 0.9379 dev_pre: 0.9596 dev_acc: 0.0000 | {'O': 350, 'I-SKILL': 88}
#
# DEV : I-SKILL : dev_f1: 0.5982 dev_rec: 0.5044 dev_pre: 0.7348 dev_acc: 0.0000 | {'B-SKILL': 123, 'O': 671, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8000 dev_rec: 0.7500 dev_pre: 0.8571 dev_acc: 0.0000 | {'B-SKILL': 1, 'O': 1}
#
# TEST : total : test_f1: 0.8873 test_rec: 0.8501 test_pre: 0.9279 test_acc: 0.9754 |
#
# TEST : O : test_f1: 0.9882 test_rec: 0.9944 test_pre: 0.9820 test_acc: 0.0000 | {'I-SKILL': 148, 'B-SKILL': 224, 'B-EDU': 3}
#
# TEST : B-SKILL : test_f1: 0.9357 test_rec: 0.9265 test_pre: 0.9451 test_acc: 0.0000 | {'O': 438, 'I-SKILL': 107}
#
# TEST : I-SKILL : test_f1: 0.5783 test_rec: 0.4651 test_pre: 0.7643 test_acc: 0.0000 | {'O': 777, 'B-SKILL': 174}
#
# TEST : B-EDU : test_f1: 0.7273 test_rec: 0.6667 test_pre: 0.8000 test_acc: 0.0000 | {'O': 5, 'B-SKILL': 1}
#
# (loss: 1.5597, epoch: 8, dev F1 = 0.8993, dev acc = 0.9791, F1 on test = 0.8873, acc on test= 0.9754), saving...
# epoch: 8	 in 200 take: 19437.805892944336 s
# DEV : total : dev_f1: 0.9032 dev_rec: 0.8739 dev_pre: 0.9346 dev_acc: 0.9800 |
#
# DEV : O : dev_f1: 0.9902 dev_rec: 0.9949 dev_pre: 0.9856 dev_acc: 0.0000 | {'I-SKILL': 166, 'B-SKILL': 177, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9508 dev_rec: 0.9477 dev_pre: 0.9539 dev_acc: 0.0000 | {'O': 317, 'I-SKILL': 52}
#
# DEV : I-SKILL : dev_f1: 0.6076 dev_rec: 0.4956 dev_pre: 0.7848 dev_acc: 0.0000 | {'B-SKILL': 145, 'O': 663, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8235 dev_rec: 0.8750 dev_pre: 0.7778 dev_acc: 0.0000 | {'B-SKILL': 1}
#
# TEST : total : test_f1: 0.8933 test_rec: 0.8599 test_pre: 0.9294 test_acc: 0.9763 |
#
# TEST : O : test_f1: 0.9886 test_rec: 0.9944 test_pre: 0.9829 test_acc: 0.0000 | {'I-SKILL': 132, 'B-SKILL': 239, 'B-EDU': 3}
#
# TEST : B-SKILL : test_f1: 0.9399 test_rec: 0.9404 test_pre: 0.9395 test_acc: 0.0000 | {'O': 379, 'I-SKILL': 63}
#
# TEST : I-SKILL : test_f1: 0.5734 test_rec: 0.4460 test_pre: 0.8026 test_acc: 0.0000 | {'O': 776, 'B-SKILL': 209}
#
# TEST : B-EDU : test_f1: 0.7273 test_rec: 0.6667 test_pre: 0.8000 test_acc: 0.0000 | {'O': 5, 'B-SKILL': 1}
#
# (loss: 1.4847, epoch: 9, dev F1 = 0.9032, dev acc = 0.9800, F1 on test = 0.8933, acc on test= 0.9763), saving...
# epoch: 9	 in 200 take: 21355.45002913475 s
# DEV : total : dev_f1: 0.9016 dev_rec: 0.8673 dev_pre: 0.9388 dev_acc: 0.9798 |
#
# DEV : O : dev_f1: 0.9901 dev_rec: 0.9956 dev_pre: 0.9847 dev_acc: 0.0000 | {'I-SKILL': 139, 'B-SKILL': 160, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9518 dev_rec: 0.9489 dev_pre: 0.9548 dev_acc: 0.0000 | {'O': 321, 'I-SKILL': 40}
#
# DEV : I-SKILL : dev_f1: 0.5764 dev_rec: 0.4501 dev_pre: 0.8013 dev_acc: 0.0000 | {'B-SKILL': 156, 'O': 725, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8235 dev_rec: 0.8750 dev_pre: 0.7778 dev_acc: 0.0000 | {'B-SKILL': 1}
#
# (loss: 1.4447, epoch: 10, dev F1 = 0.9016, dev acc = 0.9798)
# epoch: 10	 in 200 take: 23255.283227920532 s
# DEV : total : dev_f1: 0.9065 dev_rec: 0.8737 dev_pre: 0.9420 dev_acc: 0.9806 |
#
# DEV : O : dev_f1: 0.9905 dev_rec: 0.9955 dev_pre: 0.9856 dev_acc: 0.0000 | {'I-SKILL': 124, 'B-SKILL': 178, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9531 dev_rec: 0.9503 dev_pre: 0.9560 dev_acc: 0.0000 | {'O': 295, 'I-SKILL': 56}
#
# DEV : I-SKILL : dev_f1: 0.6095 dev_rec: 0.4875 dev_pre: 0.8129 dev_acc: 0.0000 | {'B-SKILL': 130, 'O': 691, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8235 dev_rec: 0.8750 dev_pre: 0.7778 dev_acc: 0.0000 | {'B-SKILL': 1}
#
# TEST : total : test_f1: 0.8955 test_rec: 0.8612 test_pre: 0.9326 test_acc: 0.9769 |
#
# TEST : O : test_f1: 0.9890 test_rec: 0.9948 test_pre: 0.9832 test_acc: 0.0000 | {'I-SKILL': 102, 'B-SKILL': 244, 'B-EDU': 3}
#
# TEST : B-SKILL : test_f1: 0.9428 test_rec: 0.9459 test_pre: 0.9397 test_acc: 0.0000 | {'O': 334, 'I-SKILL': 67}
#
# TEST : I-SKILL : test_f1: 0.5668 test_rec: 0.4331 test_pre: 0.8200 test_acc: 0.0000 | {'O': 803, 'B-SKILL': 205}
#
# TEST : B-EDU : test_f1: 0.7647 test_rec: 0.7222 test_pre: 0.8125 test_acc: 0.0000 | {'O': 4, 'B-SKILL': 1}
#
# (loss: 1.3906, epoch: 11, dev F1 = 0.9065, dev acc = 0.9806, F1 on test = 0.8955, acc on test= 0.9769), saving...
# epoch: 11	 in 200 take: 25325.44850897789 s
# DEV : total : dev_f1: 0.9073 dev_rec: 0.8857 dev_pre: 0.9300 dev_acc: 0.9805 |
#
# DEV : O : dev_f1: 0.9904 dev_rec: 0.9938 dev_pre: 0.9870 dev_acc: 0.0000 | {'I-SKILL': 230, 'B-SKILL': 187, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9536 dev_rec: 0.9514 dev_pre: 0.9559 dev_acc: 0.0000 | {'O': 279, 'I-SKILL': 64}
#
# DEV : I-SKILL : dev_f1: 0.6321 dev_rec: 0.5468 dev_pre: 0.7489 dev_acc: 0.0000 | {'B-SKILL': 123, 'O': 603, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# TEST : total : test_f1: 0.8973 test_rec: 0.8746 test_pre: 0.9212 test_acc: 0.9774 |
#
# TEST : O : test_f1: 0.9891 test_rec: 0.9932 test_pre: 0.9851 test_acc: 0.0000 | {'I-SKILL': 181, 'B-SKILL': 275, 'B-EDU': 3}
#
# TEST : B-SKILL : test_f1: 0.9443 test_rec: 0.9503 test_pre: 0.9384 test_acc: 0.0000 | {'O': 295, 'I-SKILL': 73}
#
# TEST : I-SKILL : test_f1: 0.6068 test_rec: 0.4978 test_pre: 0.7770 test_acc: 0.0000 | {'O': 707, 'B-SKILL': 186}
#
# TEST : B-EDU : test_f1: 0.7647 test_rec: 0.7222 test_pre: 0.8125 test_acc: 0.0000 | {'O': 4, 'B-SKILL': 1}
#
# (loss: 1.3570, epoch: 12, dev F1 = 0.9073, dev acc = 0.9805, F1 on test = 0.8973, acc on test= 0.9774), saving...
# epoch: 12	 in 200 take: 27322.94514799118 s
# DEV : total : dev_f1: 0.9076 dev_rec: 0.8835 dev_pre: 0.9332 dev_acc: 0.9809 |
#
# DEV : O : dev_f1: 0.9908 dev_rec: 0.9949 dev_pre: 0.9867 dev_acc: 0.0000 | {'I-SKILL': 166, 'B-SKILL': 180, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9530 dev_rec: 0.9548 dev_pre: 0.9512 dev_acc: 0.0000 | {'O': 283, 'I-SKILL': 36}
#
# DEV : I-SKILL : dev_f1: 0.6224 dev_rec: 0.5087 dev_pre: 0.8016 dev_acc: 0.0000 | {'B-SKILL': 166, 'O': 621, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# TEST : total : test_f1: 0.8987 test_rec: 0.8733 test_pre: 0.9256 test_acc: 0.9776 |
#
# TEST : O : test_f1: 0.9893 test_rec: 0.9941 test_pre: 0.9846 test_acc: 0.0000 | {'I-SKILL': 148, 'B-SKILL': 245, 'B-EDU': 3}
#
# TEST : B-SKILL : test_f1: 0.9442 test_rec: 0.9518 test_pre: 0.9368 test_acc: 0.0000 | {'O': 318, 'I-SKILL': 39}
#
# TEST : I-SKILL : test_f1: 0.5919 test_rec: 0.4646 test_pre: 0.8154 test_acc: 0.0000 | {'O': 721, 'B-SKILL': 231}
#
# TEST : B-EDU : test_f1: 0.8333 test_rec: 0.8333 test_pre: 0.8333 test_acc: 0.0000 | {'O': 3}
#
# (loss: 1.3156, epoch: 13, dev F1 = 0.9076, dev acc = 0.9809, F1 on test = 0.8987, acc on test= 0.9776), saving...
# epoch: 13	 in 200 take: 29260.532466888428 s
# DEV : total : dev_f1: 0.9104 dev_rec: 0.8837 dev_pre: 0.9387 dev_acc: 0.9815 |
#
# DEV : O : dev_f1: 0.9909 dev_rec: 0.9950 dev_pre: 0.9868 dev_acc: 0.0000 | {'I-SKILL': 184, 'B-SKILL': 153, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9552 dev_rec: 0.9487 dev_pre: 0.9618 dev_acc: 0.0000 | {'O': 301, 'I-SKILL': 61}
#
# DEV : I-SKILL : dev_f1: 0.6499 dev_rec: 0.5549 dev_pre: 0.7841 dev_acc: 0.0000 | {'B-SKILL': 113, 'O': 600, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# TEST : total : test_f1: 0.9006 test_rec: 0.8709 test_pre: 0.9323 test_acc: 0.9784 |
#
# TEST : O : test_f1: 0.9896 test_rec: 0.9947 test_pre: 0.9846 test_acc: 0.0000 | {'I-SKILL': 140, 'B-SKILL': 210, 'B-EDU': 3}
#
# TEST : B-SKILL : test_f1: 0.9460 test_rec: 0.9428 test_pre: 0.9493 test_acc: 0.0000 | {'O': 333, 'I-SKILL': 91}
#
# TEST : I-SKILL : test_f1: 0.6226 test_rec: 0.5107 test_pre: 0.7972 test_acc: 0.0000 | {'O': 707, 'B-SKILL': 163}
#
# TEST : B-EDU : test_f1: 0.8333 test_rec: 0.8333 test_pre: 0.8333 test_acc: 0.0000 | {'O': 3}
#
# (loss: 1.2944, epoch: 14, dev F1 = 0.9104, dev acc = 0.9815, F1 on test = 0.9006, acc on test= 0.9784), saving...
# epoch: 14	 in 200 take: 31319.386789798737 s
# DEV : total : dev_f1: 0.9098 dev_rec: 0.8772 dev_pre: 0.9449 dev_acc: 0.9816 |
#
# DEV : O : dev_f1: 0.9910 dev_rec: 0.9958 dev_pre: 0.9862 dev_acc: 0.0000 | {'I-SKILL': 133, 'B-SKILL': 149, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9559 dev_rec: 0.9497 dev_pre: 0.9621 dev_acc: 0.0000 | {'O': 297, 'I-SKILL': 58}
#
# DEV : I-SKILL : dev_f1: 0.6381 dev_rec: 0.5243 dev_pre: 0.8149 dev_acc: 0.0000 | {'B-SKILL': 115, 'O': 647, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# (loss: 1.2605, epoch: 15, dev F1 = 0.9098, dev acc = 0.9816)
# epoch: 15	 in 200 take: 33211.35035085678 s
# DEV : total : dev_f1: 0.9130 dev_rec: 0.8993 dev_pre: 0.9271 dev_acc: 0.9816 |
#
# DEV : O : dev_f1: 0.9909 dev_rec: 0.9931 dev_pre: 0.9888 dev_acc: 0.0000 | {'I-SKILL': 322, 'B-SKILL': 145, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9579 dev_rec: 0.9510 dev_pre: 0.9649 dev_acc: 0.0000 | {'I-SKILL': 72, 'O': 274}
#
# DEV : I-SKILL : dev_f1: 0.6742 dev_rec: 0.6334 dev_pre: 0.7206 dev_acc: 0.0000 | {'B-SKILL': 99, 'O': 488, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# TEST : total : test_f1: 0.9009 test_rec: 0.8833 test_pre: 0.9193 test_acc: 0.9784 |
#
# TEST : O : test_f1: 0.9896 test_rec: 0.9927 test_pre: 0.9865 test_acc: 0.0000 | {'I-SKILL': 280, 'B-SKILL': 208, 'B-EDU': 3}
#
# TEST : B-SKILL : test_f1: 0.9482 test_rec: 0.9452 test_pre: 0.9511 test_acc: 0.0000 | {'O': 312, 'I-SKILL': 94}
#
# TEST : I-SKILL : test_f1: 0.6461 test_rec: 0.5776 test_pre: 0.7330 test_acc: 0.0000 | {'O': 599, 'B-SKILL': 152}
#
# TEST : B-EDU : test_f1: 0.8333 test_rec: 0.8333 test_pre: 0.8333 test_acc: 0.0000 | {'O': 3}
#
# (loss: 1.2347, epoch: 16, dev F1 = 0.9130, dev acc = 0.9816, F1 on test = 0.9009, acc on test= 0.9784), saving...
# epoch: 16	 in 200 take: 35278.76392889023 s
# DEV : total : dev_f1: 0.9152 dev_rec: 0.8907 dev_pre: 0.9410 dev_acc: 0.9821 |
#
# DEV : O : dev_f1: 0.9912 dev_rec: 0.9950 dev_pre: 0.9874 dev_acc: 0.0000 | {'I-SKILL': 178, 'B-SKILL': 159, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9571 dev_rec: 0.9541 dev_pre: 0.9602 dev_acc: 0.0000 | {'O': 275, 'I-SKILL': 49}
#
# DEV : I-SKILL : dev_f1: 0.6606 dev_rec: 0.5630 dev_pre: 0.7991 dev_acc: 0.0000 | {'B-SKILL': 120, 'O': 580, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# TEST : total : test_f1: 0.9035 test_rec: 0.8774 test_pre: 0.9311 test_acc: 0.9790 |
#
# TEST : O : test_f1: 0.9899 test_rec: 0.9944 test_pre: 0.9854 test_acc: 0.0000 | {'I-SKILL': 146, 'B-SKILL': 230, 'B-EDU': 2}
#
# TEST : B-SKILL : test_f1: 0.9479 test_rec: 0.9486 test_pre: 0.9472 test_acc: 0.0000 | {'O': 307, 'I-SKILL': 74}
#
# TEST : I-SKILL : test_f1: 0.6380 test_rec: 0.5264 test_pre: 0.8097 test_acc: 0.0000 | {'O': 680, 'B-SKILL': 162}
#
# TEST : B-EDU : test_f1: 0.8889 test_rec: 0.8889 test_pre: 0.8889 test_acc: 0.0000 | {'O': 2}
#
# (loss: 1.1924, epoch: 17, dev F1 = 0.9152, dev acc = 0.9821, F1 on test = 0.9035, acc on test= 0.9790), saving...
# epoch: 17	 in 200 take: 37137.57064080238 s
# DEV : total : dev_f1: 0.9113 dev_rec: 0.8722 dev_pre: 0.9542 dev_acc: 0.9816 |
#
# DEV : O : dev_f1: 0.9908 dev_rec: 0.9967 dev_pre: 0.9851 dev_acc: 0.0000 | {'I-SKILL': 92, 'B-SKILL': 133, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9563 dev_rec: 0.9470 dev_pre: 0.9658 dev_acc: 0.0000 | {'O': 324, 'I-SKILL': 50}
#
# DEV : I-SKILL : dev_f1: 0.6306 dev_rec: 0.5012 dev_pre: 0.8499 dev_acc: 0.0000 | {'B-SKILL': 104, 'O': 695, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# (loss: 1.1696, epoch: 18, dev F1 = 0.9113, dev acc = 0.9816)
# epoch: 18	 in 200 take: 39057.3001101017 s
# DEV : total : dev_f1: 0.9153 dev_rec: 0.8895 dev_pre: 0.9427 dev_acc: 0.9823 |
#
# DEV : O : dev_f1: 0.9913 dev_rec: 0.9952 dev_pre: 0.9874 dev_acc: 0.0000 | {'I-SKILL': 159, 'B-SKILL': 164, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9582 dev_rec: 0.9576 dev_pre: 0.9589 dev_acc: 0.0000 | {'O': 263, 'I-SKILL': 35, 'B-EDU': 1}
#
# DEV : I-SKILL : dev_f1: 0.6572 dev_rec: 0.5486 dev_pre: 0.8194 dev_acc: 0.0000 | {'B-SKILL': 126, 'O': 597, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8421 dev_rec: 1.0000 dev_pre: 0.7273 dev_acc: 0.0000 | {}
#
# TEST : total : test_f1: 0.9051 test_rec: 0.8776 test_pre: 0.9344 test_acc: 0.9792 |
#
# TEST : O : test_f1: 0.9901 test_rec: 0.9948 test_pre: 0.9854 test_acc: 0.0000 | {'I-SKILL': 137, 'B-SKILL': 211, 'B-EDU': 1}
#
# TEST : B-SKILL : test_f1: 0.9496 test_rec: 0.9526 test_pre: 0.9465 test_acc: 0.0000 | {'O': 295, 'I-SKILL': 56}
#
# TEST : I-SKILL : test_f1: 0.6255 test_rec: 0.5045 test_pre: 0.8229 test_acc: 0.0000 | {'O': 693, 'B-SKILL': 188}
#
# TEST : B-EDU : test_f1: 0.8824 test_rec: 0.8333 test_pre: 0.9375 test_acc: 0.0000 | {'O': 3}
#
# (loss: 1.1554, epoch: 19, dev F1 = 0.9153, dev acc = 0.9823, F1 on test = 0.9051, acc on test= 0.9792), saving...
# epoch: 19	 in 200 take: 41016.62261605263 s
# DEV : total : dev_f1: 0.9148 dev_rec: 0.8902 dev_pre: 0.9407 dev_acc: 0.9821 |
#
# DEV : O : dev_f1: 0.9911 dev_rec: 0.9949 dev_pre: 0.9873 dev_acc: 0.0000 | {'I-SKILL': 172, 'B-SKILL': 172, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9560 dev_rec: 0.9528 dev_pre: 0.9592 dev_acc: 0.0000 | {'O': 290, 'I-SKILL': 43}
#
# DEV : I-SKILL : dev_f1: 0.6703 dev_rec: 0.5717 dev_pre: 0.8101 dev_acc: 0.0000 | {'B-SKILL': 114, 'O': 572, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# (loss: 1.1199, epoch: 20, dev F1 = 0.9148, dev acc = 0.9821)
# epoch: 20	 in 200 take: 42834.428763866425 s
# DEV : total : dev_f1: 0.9160 dev_rec: 0.9036 dev_pre: 0.9289 dev_acc: 0.9820 |
#
# DEV : O : dev_f1: 0.9911 dev_rec: 0.9932 dev_pre: 0.9890 dev_acc: 0.0000 | {'I-SKILL': 282, 'B-SKILL': 176, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9577 dev_rec: 0.9565 dev_pre: 0.9588 dev_acc: 0.0000 | {'O': 257, 'I-SKILL': 50}
#
# DEV : I-SKILL : dev_f1: 0.6803 dev_rec: 0.6222 dev_pre: 0.7504 dev_acc: 0.0000 | {'B-SKILL': 114, 'O': 491, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# TEST : total : test_f1: 0.9071 test_rec: 0.8908 test_pre: 0.9241 test_acc: 0.9794 |
#
# TEST : O : test_f1: 0.9901 test_rec: 0.9932 test_pre: 0.9870 test_acc: 0.0000 | {'I-SKILL': 241, 'B-SKILL': 214, 'B-EDU': 1}
#
# TEST : B-SKILL : test_f1: 0.9506 test_rec: 0.9530 test_pre: 0.9482 test_acc: 0.0000 | {'O': 283, 'I-SKILL': 65}
#
# TEST : I-SKILL : test_f1: 0.6537 test_rec: 0.5692 test_pre: 0.7678 test_acc: 0.0000 | {'O': 594, 'B-SKILL': 172}
#
# TEST : B-EDU : test_f1: 0.8824 test_rec: 0.8333 test_pre: 0.9375 test_acc: 0.0000 | {'O': 3}
#
# (loss: 1.1155, epoch: 21, dev F1 = 0.9160, dev acc = 0.9820, F1 on test = 0.9071, acc on test= 0.9794), saving...
# epoch: 21	 in 200 take: 44912.53451013565 s
# DEV : total : dev_f1: 0.9171 dev_rec: 0.8888 dev_pre: 0.9472 dev_acc: 0.9826 |
#
# DEV : O : dev_f1: 0.9913 dev_rec: 0.9956 dev_pre: 0.9871 dev_acc: 0.0000 | {'I-SKILL': 172, 'B-SKILL': 125, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9592 dev_rec: 0.9503 dev_pre: 0.9682 dev_acc: 0.0000 | {'O': 302, 'I-SKILL': 49}
#
# DEV : I-SKILL : dev_f1: 0.6742 dev_rec: 0.5786 dev_pre: 0.8077 dev_acc: 0.0000 | {'B-SKILL': 95, 'O': 580, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# TEST : total : test_f1: 0.9076 test_rec: 0.8768 test_pre: 0.9407 test_acc: 0.9799 |
#
# TEST : O : test_f1: 0.9902 test_rec: 0.9955 test_pre: 0.9850 test_acc: 0.0000 | {'I-SKILL': 139, 'B-SKILL': 161, 'B-EDU': 1}
#
# TEST : B-SKILL : test_f1: 0.9511 test_rec: 0.9448 test_pre: 0.9575 test_acc: 0.0000 | {'O': 340, 'I-SKILL': 69}
#
# TEST : I-SKILL : test_f1: 0.6494 test_rec: 0.5371 test_pre: 0.8212 test_acc: 0.0000 | {'O': 673, 'B-SKILL': 150}
#
# TEST : B-EDU : test_f1: 0.8824 test_rec: 0.8333 test_pre: 0.9375 test_acc: 0.0000 | {'O': 3}
#
# (loss: 1.0865, epoch: 22, dev F1 = 0.9171, dev acc = 0.9826, F1 on test = 0.9076, acc on test= 0.9799), saving...
# epoch: 22	 in 200 take: 46807.20781803131 s
# DEV : total : dev_f1: 0.9192 dev_rec: 0.8887 dev_pre: 0.9518 dev_acc: 0.9832 |
#
# DEV : O : dev_f1: 0.9917 dev_rec: 0.9963 dev_pre: 0.9872 dev_acc: 0.0000 | {'I-SKILL': 110, 'B-SKILL': 142, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9601 dev_rec: 0.9569 dev_pre: 0.9632 dev_acc: 0.0000 | {'O': 272, 'I-SKILL': 32}
#
# DEV : I-SKILL : dev_f1: 0.6717 dev_rec: 0.5505 dev_pre: 0.8615 dev_acc: 0.0000 | {'B-SKILL': 116, 'O': 604, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# TEST : total : test_f1: 0.9071 test_rec: 0.8755 test_pre: 0.9410 test_acc: 0.9797 |
#
# TEST : O : test_f1: 0.9902 test_rec: 0.9957 test_pre: 0.9848 test_acc: 0.0000 | {'I-SKILL': 103, 'B-SKILL': 185, 'B-EDU': 1}
#
# TEST : B-SKILL : test_f1: 0.9512 test_rec: 0.9513 test_pre: 0.9510 test_acc: 0.0000 | {'O': 310, 'I-SKILL': 51}
#
# TEST : I-SKILL : test_f1: 0.6288 test_rec: 0.4983 test_pre: 0.8519 test_acc: 0.0000 | {'O': 714, 'B-SKILL': 178}
#
# TEST : B-EDU : test_f1: 0.8485 test_rec: 0.7778 test_pre: 0.9333 test_acc: 0.0000 | {'O': 4}
#
# (loss: 1.0672, epoch: 23, dev F1 = 0.9192, dev acc = 0.9832, F1 on test = 0.9071, acc on test= 0.9797), saving...
# epoch: 23	 in 200 take: 48726.34534406662 s
# DEV : total : dev_f1: 0.9187 dev_rec: 0.9033 dev_pre: 0.9345 dev_acc: 0.9829 |
#
# DEV : O : dev_f1: 0.9916 dev_rec: 0.9942 dev_pre: 0.9890 dev_acc: 0.0000 | {'I-SKILL': 224, 'B-SKILL': 170, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9578 dev_rec: 0.9578 dev_pre: 0.9579 dev_acc: 0.0000 | {'O': 264, 'I-SKILL': 34}
#
# DEV : I-SKILL : dev_f1: 0.6942 dev_rec: 0.6172 dev_pre: 0.7933 dev_acc: 0.0000 | {'B-SKILL': 127, 'O': 486, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# (loss: 1.0588, epoch: 24, dev F1 = 0.9187, dev acc = 0.9829)
# epoch: 24	 in 200 take: 50575.485047101974 s
# DEV : total : dev_f1: 0.9193 dev_rec: 0.8995 dev_pre: 0.9400 dev_acc: 0.9832 |
#
# DEV : O : dev_f1: 0.9917 dev_rec: 0.9948 dev_pre: 0.9887 dev_acc: 0.0000 | {'I-SKILL': 201, 'B-SKILL': 150, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9595 dev_rec: 0.9562 dev_pre: 0.9628 dev_acc: 0.0000 | {'O': 265, 'I-SKILL': 44}
#
# DEV : I-SKILL : dev_f1: 0.6956 dev_rec: 0.6147 dev_pre: 0.8010 dev_acc: 0.0000 | {'B-SKILL': 111, 'O': 506, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# TEST : total : test_f1: 0.9098 test_rec: 0.8877 test_pre: 0.9329 test_acc: 0.9801 |
#
# TEST : O : test_f1: 0.9905 test_rec: 0.9943 test_pre: 0.9867 test_acc: 0.0000 | {'I-SKILL': 189, 'B-SKILL': 189, 'B-EDU': 1}
#
# TEST : B-SKILL : test_f1: 0.9513 test_rec: 0.9507 test_pre: 0.9519 test_acc: 0.0000 | {'O': 294, 'I-SKILL': 71}
#
# TEST : I-SKILL : test_f1: 0.6619 test_rec: 0.5669 test_pre: 0.7950 test_acc: 0.0000 | {'O': 603, 'B-SKILL': 167}
#
# TEST : B-EDU : test_f1: 0.8824 test_rec: 0.8333 test_pre: 0.9375 test_acc: 0.0000 | {'O': 3}
#
# (loss: 1.0366, epoch: 25, dev F1 = 0.9193, dev acc = 0.9832, F1 on test = 0.9098, acc on test= 0.9801), saving...
# epoch: 25	 in 200 take: 52782.12683391571 s
# DEV : total : dev_f1: 0.9185 dev_rec: 0.8869 dev_pre: 0.9523 dev_acc: 0.9831 |
#
# DEV : O : dev_f1: 0.9916 dev_rec: 0.9961 dev_pre: 0.9871 dev_acc: 0.0000 | {'I-SKILL': 125, 'B-SKILL': 135, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9595 dev_rec: 0.9520 dev_pre: 0.9672 dev_acc: 0.0000 | {'O': 289, 'I-SKILL': 50}
#
# DEV : I-SKILL : dev_f1: 0.6808 dev_rec: 0.5723 dev_pre: 0.8399 dev_acc: 0.0000 | {'B-SKILL': 93, 'O': 592, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# (loss: 1.0150, epoch: 26, dev F1 = 0.9185, dev acc = 0.9831)
# epoch: 26	 in 200 take: 54584.203094005585 s
# DEV : total : dev_f1: 0.9186 dev_rec: 0.8903 dev_pre: 0.9487 dev_acc: 0.9831 |
#
# DEV : O : dev_f1: 0.9916 dev_rec: 0.9959 dev_pre: 0.9874 dev_acc: 0.0000 | {'I-SKILL': 124, 'B-SKILL': 153, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9589 dev_rec: 0.9564 dev_pre: 0.9614 dev_acc: 0.0000 | {'O': 277, 'I-SKILL': 31}
#
# DEV : I-SKILL : dev_f1: 0.6774 dev_rec: 0.5617 dev_pre: 0.8532 dev_acc: 0.0000 | {'B-SKILL': 118, 'O': 584, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# (loss: 0.9979, epoch: 27, dev F1 = 0.9186, dev acc = 0.9831)
# epoch: 27	 in 200 take: 56412.48590898514 s
# DEV : total : dev_f1: 0.9212 dev_rec: 0.9008 dev_pre: 0.9424 dev_acc: 0.9836 |
#
# DEV : O : dev_f1: 0.9918 dev_rec: 0.9949 dev_pre: 0.9888 dev_acc: 0.0000 | {'I-SKILL': 206, 'B-SKILL': 140, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9604 dev_rec: 0.9545 dev_pre: 0.9664 dev_acc: 0.0000 | {'O': 268, 'I-SKILL': 53}
#
# DEV : I-SKILL : dev_f1: 0.7067 dev_rec: 0.6347 dev_pre: 0.7972 dev_acc: 0.0000 | {'B-SKILL': 94, 'O': 491, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# TEST : total : test_f1: 0.9103 test_rec: 0.8879 test_pre: 0.9340 test_acc: 0.9805 |
#
# TEST : O : test_f1: 0.9906 test_rec: 0.9945 test_pre: 0.9867 test_acc: 0.0000 | {'I-SKILL': 187, 'B-SKILL': 181, 'B-EDU': 1}
#
# TEST : B-SKILL : test_f1: 0.9530 test_rec: 0.9509 test_pre: 0.9551 test_acc: 0.0000 | {'O': 291, 'I-SKILL': 73}
#
# TEST : I-SKILL : test_f1: 0.6688 test_rec: 0.5759 test_pre: 0.7975 test_acc: 0.0000 | {'O': 604, 'B-SKILL': 150}
#
# TEST : B-EDU : test_f1: 0.8824 test_rec: 0.8333 test_pre: 0.9375 test_acc: 0.0000 | {'O': 3}
#
# (loss: 1.0034, epoch: 28, dev F1 = 0.9212, dev acc = 0.9836, F1 on test = 0.9103, acc on test= 0.9805), saving...
# epoch: 28	 in 200 take: 58246.26559686661 s
# DEV : total : dev_f1: 0.9207 dev_rec: 0.8940 dev_pre: 0.9491 dev_acc: 0.9836 |
#
# DEV : O : dev_f1: 0.9918 dev_rec: 0.9958 dev_pre: 0.9878 dev_acc: 0.0000 | {'I-SKILL': 155, 'B-SKILL': 129, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9613 dev_rec: 0.9544 dev_pre: 0.9682 dev_acc: 0.0000 | {'O': 282, 'I-SKILL': 40}
#
# DEV : I-SKILL : dev_f1: 0.6964 dev_rec: 0.5991 dev_pre: 0.8313 dev_acc: 0.0000 | {'B-SKILL': 92, 'O': 550, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# (loss: 0.9703, epoch: 29, dev F1 = 0.9207, dev acc = 0.9836)
# epoch: 29	 in 200 take: 60102.46686792374 s
# DEV : total : dev_f1: 0.9222 dev_rec: 0.8930 dev_pre: 0.9533 dev_acc: 0.9839 |
#
# DEV : O : dev_f1: 0.9919 dev_rec: 0.9963 dev_pre: 0.9876 dev_acc: 0.0000 | {'I-SKILL': 119, 'B-SKILL': 129, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9614 dev_rec: 0.9554 dev_pre: 0.9676 dev_acc: 0.0000 | {'O': 279, 'I-SKILL': 36}
#
# DEV : I-SKILL : dev_f1: 0.6966 dev_rec: 0.5860 dev_pre: 0.8584 dev_acc: 0.0000 | {'B-SKILL': 97, 'O': 566, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# TEST : total : test_f1: 0.9104 test_rec: 0.8807 test_pre: 0.9421 test_acc: 0.9805 |
#
# TEST : O : test_f1: 0.9906 test_rec: 0.9958 test_pre: 0.9855 test_acc: 0.0000 | {'I-SKILL': 117, 'B-SKILL': 163, 'B-EDU': 1}
#
# TEST : B-SKILL : test_f1: 0.9517 test_rec: 0.9487 test_pre: 0.9548 test_acc: 0.0000 | {'O': 325, 'I-SKILL': 55}
#
# TEST : I-SKILL : test_f1: 0.6561 test_rec: 0.5354 test_pre: 0.8470 test_acc: 0.0000 | {'O': 656, 'B-SKILL': 170}
#
# TEST : B-EDU : test_f1: 0.8824 test_rec: 0.8333 test_pre: 0.9375 test_acc: 0.0000 | {'O': 3}
#
# (loss: 0.9499, epoch: 30, dev F1 = 0.9222, dev acc = 0.9839, F1 on test = 0.9104, acc on test= 0.9805), saving...
# epoch: 30	 in 200 take: 62010.586591959 s
# DEV : total : dev_f1: 0.9241 dev_rec: 0.9043 dev_pre: 0.9449 dev_acc: 0.9840 |
#
# DEV : O : dev_f1: 0.9920 dev_rec: 0.9950 dev_pre: 0.9890 dev_acc: 0.0000 | {'I-SKILL': 180, 'B-SKILL': 158, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9607 dev_rec: 0.9574 dev_pre: 0.9640 dev_acc: 0.0000 | {'O': 264, 'I-SKILL': 37}
#
# DEV : I-SKILL : dev_f1: 0.7212 dev_rec: 0.6403 dev_pre: 0.8256 dev_acc: 0.0000 | {'B-SKILL': 94, 'O': 482, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# TEST : total : test_f1: 0.9130 test_rec: 0.8899 test_pre: 0.9374 test_acc: 0.9810 |
#
# TEST : O : test_f1: 0.9908 test_rec: 0.9949 test_pre: 0.9868 test_acc: 0.0000 | {'I-SKILL': 160, 'B-SKILL': 179, 'B-EDU': 1}
#
# TEST : B-SKILL : test_f1: 0.9537 test_rec: 0.9532 test_pre: 0.9542 test_acc: 0.0000 | {'O': 293, 'I-SKILL': 54}
#
# TEST : I-SKILL : test_f1: 0.6769 test_rec: 0.5731 test_pre: 0.8264 test_acc: 0.0000 | {'O': 599, 'B-SKILL': 160}
#
# TEST : B-EDU : test_f1: 0.8824 test_rec: 0.8333 test_pre: 0.9375 test_acc: 0.0000 | {'O': 3}
#
# (loss: 0.9468, epoch: 31, dev F1 = 0.9241, dev acc = 0.9840, F1 on test = 0.9130, acc on test= 0.9810), saving...
# epoch: 31	 in 200 take: 63869.25513601303 s
# DEV : total : dev_f1: 0.9233 dev_rec: 0.9034 dev_pre: 0.9441 dev_acc: 0.9839 |
#
# DEV : O : dev_f1: 0.9920 dev_rec: 0.9949 dev_pre: 0.9891 dev_acc: 0.0000 | {'I-SKILL': 199, 'B-SKILL': 142, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9618 dev_rec: 0.9566 dev_pre: 0.9669 dev_acc: 0.0000 | {'I-SKILL': 48, 'O': 258}
#
# DEV : I-SKILL : dev_f1: 0.7141 dev_rec: 0.6409 dev_pre: 0.8063 dev_acc: 0.0000 | {'B-SKILL': 89, 'O': 486, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# (loss: 0.9346, epoch: 32, dev F1 = 0.9233, dev acc = 0.9839)
# epoch: 32	 in 200 take: 65736.51935195923 s
# DEV : total : dev_f1: 0.9234 dev_rec: 0.9084 dev_pre: 0.9389 dev_acc: 0.9837 |
#
# DEV : O : dev_f1: 0.9918 dev_rec: 0.9942 dev_pre: 0.9895 dev_acc: 0.0000 | {'I-SKILL': 198, 'B-SKILL': 191, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9601 dev_rec: 0.9620 dev_pre: 0.9581 dev_acc: 0.0000 | {'I-SKILL': 28, 'O': 240}
#
# DEV : I-SKILL : dev_f1: 0.7167 dev_rec: 0.6372 dev_pre: 0.8189 dev_acc: 0.0000 | {'B-SKILL': 106, 'O': 475, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# (loss: 0.9201, epoch: 33, dev F1 = 0.9234, dev acc = 0.9837)
# epoch: 33	 in 200 take: 67720.92283606529 s
# DEV : total : dev_f1: 0.9259 dev_rec: 0.9045 dev_pre: 0.9483 dev_acc: 0.9843 |
#
# DEV : O : dev_f1: 0.9921 dev_rec: 0.9953 dev_pre: 0.9890 dev_acc: 0.0000 | {'I-SKILL': 187, 'B-SKILL': 132, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9627 dev_rec: 0.9561 dev_pre: 0.9694 dev_acc: 0.0000 | {'I-SKILL': 45, 'O': 265}
#
# DEV : I-SKILL : dev_f1: 0.7223 dev_rec: 0.6471 dev_pre: 0.8173 dev_acc: 0.0000 | {'B-SKILL': 81, 'O': 484, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8889 dev_rec: 1.0000 dev_pre: 0.8000 dev_acc: 0.0000 | {}
#
# TEST : total : test_f1: 0.9135 test_rec: 0.8901 test_pre: 0.9382 test_acc: 0.9810 |
#
# TEST : O : test_f1: 0.9908 test_rec: 0.9949 test_pre: 0.9868 test_acc: 0.0000 | {'I-SKILL': 181, 'B-SKILL': 160, 'B-EDU': 1}
#
# TEST : B-SKILL : test_f1: 0.9548 test_rec: 0.9513 test_pre: 0.9583 test_acc: 0.0000 | {'O': 298, 'I-SKILL': 63}
#
# TEST : I-SKILL : test_f1: 0.6784 test_rec: 0.5838 test_pre: 0.8097 test_acc: 0.0000 | {'O': 593, 'B-SKILL': 147}
#
# TEST : B-EDU : test_f1: 0.8824 test_rec: 0.8333 test_pre: 0.9375 test_acc: 0.0000 | {'O': 3}
#
# (loss: 0.9037, epoch: 34, dev F1 = 0.9259, dev acc = 0.9843, F1 on test = 0.9135, acc on test= 0.9810), saving...
# epoch: 34	 in 200 take: 69581.75061106682 s
# DEV : total : dev_f1: 0.9246 dev_rec: 0.9074 dev_pre: 0.9425 dev_acc: 0.9842 |
#
# DEV : O : dev_f1: 0.9921 dev_rec: 0.9947 dev_pre: 0.9895 dev_acc: 0.0000 | {'I-SKILL': 221, 'B-SKILL': 138, 'B-EDU': 1}
#
# DEV : B-SKILL : dev_f1: 0.9624 dev_rec: 0.9561 dev_pre: 0.9688 dev_acc: 0.0000 | {'I-SKILL': 50, 'O': 259, 'B-EDU': 1}
#
# DEV : I-SKILL : dev_f1: 0.7254 dev_rec: 0.6652 dev_pre: 0.7975 dev_acc: 0.0000 | {'B-SKILL': 79, 'O': 457, 'B-EDU': 1}
#
# DEV : B-EDU : dev_f1: 0.8421 dev_rec: 1.0000 dev_pre: 0.7273 dev_acc: 0.0000 | {}
#
# (loss: 0.8894, epoch: 35, dev F1 = 0.9246, dev acc = 0.9842)
# epoch: 35	 in 200 take: 71985.40188193321 s
#  - Tot it 1501 (epoch 36): 1495it [24:14,  3.46s/it]^C
# Traceback (most recent call last):
#   File "models/LM-LSTM-CRF/train_wc.py", line 191, in <module>
#     cfs, _ = ner_model.word_pre_train_forward(f_f, cf_p)
#   File "/Users/nir.konky/nir/nlp/NER-Course-Nir/models/LM-LSTM-CRF/model/lm_lstm_crf.py", line 151, in word_pre_train_forward
#     lstm_out, hidden = self.forw_char_lstm(d_embeds)
#   File "/Users/nir.konky/Library/Python/3.8/lib/python/site-packages/torch/nn/modules/module.py", line 1051, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/nir.konky/Library/Python/3.8/lib/python/site-packages/torch/nn/modules/rnn.py", line 679, in forward
#     result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
# KeyboardInterrupt

# %% [markdown]
# ##### LM-LSTM-CRF F1 score, is 91.3±94.3

# %% [markdown]
# ### FlairNLP
# Github link: https://github.com/flairNLP/flair
# Readme: https://github.com/flairNLP/flair/blob/master/README.md
#
# #### NLP Progress
# - Flair embeddings (Akbik et al., 2018)♦
# - F1: 93.09
# - Description: Contextual String Embeddings for Sequence Labeling
#
# #### Description
#
# A powerful NLP library. Flair allows to apply state-of-the-art natural language processing (NLP) models, such as named entity recognition (NER), sentiment analysis, part-of-speech tagging (PoS), special support for biomedical data, sense disambiguation and classification, with support for a rapidly growing number of languages.
#
# A text embedding library. Flair has simple interfaces that allow to use and combine different word and document embeddings, including proposed Flair embeddings and various transformers.
#
# A PyTorch NLP framework

# %%
#Install requiremnts
# !pip3 install flair

# %%
from flair.data import Corpus
from flair.datasets import ColumnCorpus
from flair.embeddings import WordEmbeddings, StackedEmbeddings, FlairEmbeddings

columns = {0 : 'text', 3: 'ner'}

# 1. get the corpus
corpus: Corpus = ColumnCorpus("dataset/split_dataset", columns,
 train_file = 'conllpp_train.txt',
 test_file = 'conllpp_test.txt',
 dev_file = 'conllpp_dev.txt')

# 2. what label do we want to predict?
tag_type = 'ner'

# 3. make the label dictionary from the corpus
tag_dictionary = corpus.make_tag_dictionary(tag_type=tag_type)
print(tag_dictionary)

embedding_types = [

    # GloVe embeddings
    WordEmbeddings('glove'),

    # contextual string embeddings, forward
    FlairEmbeddings('news-forward'),

    # contextual string embeddings, backward
    FlairEmbeddings('news-backward'),
]

embeddings = StackedEmbeddings(embeddings=embedding_types)

# 5. initialize sequence tagger
from flair.models import SequenceTagger

tagger = SequenceTagger(hidden_size=256,
                        embeddings=embeddings,
                        tag_dictionary=tag_dictionary,
                        tag_type=tag_type)

# 6. initialize trainer
from flair.trainers import ModelTrainer

trainer = ModelTrainer(tagger, corpus)

# 7. run training
trainer.train('resources/taggers/ner-english',
              train_with_dev=True,
              max_epochs=15)
# Out:
# 2023-06-03 10:35:10,187 Reading data from dataset/split_dataset
# 2023-06-03 10:35:10,187 Train: dataset/split_dataset/conllpp_train.txt
# 2023-06-03 10:35:10,187 Dev: dataset/split_dataset/conllpp_dev.txt
# 2023-06-03 10:35:10,187 Test: dataset/split_dataset/conllpp_test.txt
# Corpus: 14999 train + 3086 dev + 3096 test sentences
# <flair.data.Dictionary object at 0x1077d0f70>
# 2023-06-03 10:35:15,399 ----------------------------------------------------------------------------------------------------
# 2023-06-03 10:35:15,399 Model: "SequenceTagger(
#   (embeddings): StackedEmbeddings(
#     (list_embedding_0): WordEmbeddings('glove')
#     (list_embedding_1): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.05, inplace=False)
#         (encoder): Embedding(300, 100)
#         (rnn): LSTM(100, 2048)
#         (decoder): Linear(in_features=2048, out_features=300, bias=True)
#       )
#     )
#     (list_embedding_2): FlairEmbeddings(
#       (lm): LanguageModel(
#         (drop): Dropout(p=0.05, inplace=False)
#         (encoder): Embedding(300, 100)
#         (rnn): LSTM(100, 2048)
#         (decoder): Linear(in_features=2048, out_features=300, bias=True)
#       )
#     )
#   )
#   (word_dropout): WordDropout(p=0.05)
#   (locked_dropout): LockedDropout(p=0.5)
#   (embedding2nn): Linear(in_features=4196, out_features=4196, bias=True)
#   (rnn): LSTM(4196, 256, bidirectional=True)
#   (linear): Linear(in_features=512, out_features
p: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLarea  tp: 3 - fp: 0 - fn: 2 - tn: 3 - precision: 1.0000 - recall: 0.6000 - accuracy: 0.6000 - f1-score: 0.7500
# SKILLassessment tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLassessments tp: 1 - fp: 10 - fn: 0 - tn: 1 - precision: 0.0909 - recall: 1.0000 - accuracy: 0.0909 - f1-score: 0.1667
# SKILLassignments tp: 17 - fp: 2 - fn: 0 - tn: 17 - precision: 0.8947 - recall: 1.0000 - accuracy: 0.8947 - f1-score: 0.9444
# SKILLassist tp: 1 - fp: 0 - fn: 0 - tn: 1 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - f1-score: 1.0000
# SKILLassistance tp: 0 - fp: 0 - fn: 4 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLassistant tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLassurance tp: 2 - fp: 2 - fn: 11 - tn: 2 - precision: 0.5000 - recall: 0.1538 - accuracy: 0.1333 - f1-score: 0.2352
# SKILLattitude tp: 1 - fp: 1 - fn: 1 - tn: 1 - precision: 0.5000 - recall: 0.5000 - accuracy: 0.3333 - f1-score: 0.5000
# SKILLbalance tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLbanking tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLbased tp: 0 - fp: 0 - fn: 9 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLbasic tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLbrowser tp: 5 - fp: 2 - fn: 0 - tn: 5 - precision: 0.7143 - recall: 1.0000 - accuracy: 0.7143 - f1-score: 0.8333
# SKILLbuild tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLbuilding tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLbus   tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLbusiness tp: 5 - fp: 9 - fn: 9 - tn: 5 - precision: 0.3571 - recall: 0.3571 - accuracy: 0.2174 - f1-score: 0.3571
# SKILLcalling tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLcare  tp: 121 - fp: 25 - fn: 41 - tn: 121 - precision: 0.8288 - recall: 0.7469 - accuracy: 0.6471 - f1-score: 0.7857
# SKILLcaring tp: 11 - fp: 0 - fn: 0 - tn: 11 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - f1-score: 1.0000
# SKILLcase  tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLcases tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLcentered tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLcentre tp: 0 - fp: 0 - fn: 4 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLcertification tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLchain tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLchanges tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLchef  tp: 29 - fp: 7 - fn: 2 - tn: 29 - precision: 0.8056 - recall: 0.9355 - accuracy: 0.7632 - f1-score: 0.8657
# SKILLchefs tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLclearance tp: 0 - fp: 1 - fn: 0 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLclinical tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLclose tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLcoding tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLcommunication tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLcompliance tp: 0 - fp: 1 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLcomposition tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLconsultant tp: 0 - fp: 1 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLconsultants tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLcontinues tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLcontrol tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLcontroller tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLcoordinator tp: 9 - fp: 9 - fn: 20 - tn: 9 - precision: 0.5000 - recall: 0.3103 - accuracy: 0.2368 - f1-score: 0.3829
# SKILLcoordinators tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLculture tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLcustomers tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLdata  tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLdatabases tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLdemand tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLdental tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLdescription tp: 7 - fp: 7 - fn: 3 - tn: 7 - precision: 0.5000 - recall: 0.7000 - accuracy: 0.4118 - f1-score: 0.5833
# SKILLdesign tp: 3 - fp: 2 - fn: 10 - tn: 3 - precision: 0.6000 - recall: 0.2308 - accuracy: 0.2000 - f1-score: 0.3334
# SKILLdesigning tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLdesigns tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLdevelop tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLdeveloper tp: 0 - fp: 0 - fn: 9 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLdevelopers tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLdevelopment tp: 13 - fp: 26 - fn: 25 - tn: 13 - precision: 0.3333 - recall: 0.3421 - accuracy: 0.2031 - f1-score: 0.3376
# SKILLdirectory tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLdisorder tp: 1 - fp: 3 - fn: 1 - tn: 1 - precision: 0.2500 - recall: 0.5000 - accuracy: 0.2000 - f1-score: 0.3333
# SKILLdiverse tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLdocuments tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLefficiency tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLemails tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLenergy tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLengineer tp: 20 - fp: 22 - fn: 10 - tn: 20 - precision: 0.4762 - recall: 0.6667 - accuracy: 0.3846 - f1-score: 0.5556
# SKILLengineering tp: 1 - fp: 2 - fn: 20 - tn: 1 - precision: 0.3333 - recall: 0.0476 - accuracy: 0.0435 - f1-score: 0.0833
# SKILLengineers tp: 0 - fp: 0 - fn: 4 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLenquiries tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLenvironment tp: 5 - fp: 2 - fn: 2 - tn: 5 - precision: 0.7143 - recall: 0.7143 - accuracy: 0.5556 - f1-score: 0.7143
# SKILLenvironments tp: 0 - fp: 0 - fn: 5 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLequipment tp: 0 - fp: 1 - fn: 0 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLestate tp: 0 - fp: 1 - fn: 0 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLexcellent tp: 2 - fp: 0 - fn: 0 - tn: 2 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - f1-score: 1.0000
# SKILLexchange tp: 0 - fp: 0 - fn: 4 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLexecutive tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLexperience tp: 0 - fp: 0 - fn: 4 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLfinance tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLfocus tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLframework tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLfunctions tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLgas   tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLgathered tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLgeneration tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLgovernance tp: 0 - fp: 0 - fn: 5 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLhandbook tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLhandling tp: 1 - fp: 1 - fn: 0 - tn: 1 - precision: 0.5000 - recall: 1.0000 - accuracy: 0.5000 - f1-score: 0.6667
# SKILLhealth tp: 48 - fp: 2 - fn: 3 - tn: 48 - precision: 0.9600 - recall: 0.9412 - accuracy: 0.9057 - f1-score: 0.9505
# SKILLhoc   tp: 5 - fp: 0 - fn: 0 - tn: 5 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - f1-score: 1.0000
# SKILLhome  tp: 238 - fp: 40 - fn: 24 - tn: 238 - precision: 0.8561 - recall: 0.9084 - accuracy: 0.7881 - f1-score: 0.8815
# SKILLhospital tp: 2 - fp: 2 - fn: 0 - tn: 2 - precision: 0.5000 - recall: 1.0000 - accuracy: 0.5000 - f1-score: 0.6667
# SKILLhousing tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLhygiene tp: 0 - fp: 0 - fn: 5 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLideas tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLillustrator tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLimprovement tp: 1 - fp: 0 - fn: 1 - tn: 1 - precision: 1.0000 - recall: 0.5000 - accuracy: 0.5000 - f1-score: 0.6667
# SKILLincidents tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLindustries tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLindustry tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLinformation tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLinfrastructure tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLinitiation tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLinnovation tp: 0 - fp: 0 - fn: 5 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLinstruction tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLinstructor tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLinsurance tp: 0 - fp: 2 - fn: 0 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLintegration tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLintelligence tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLinventor tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLinvestigators tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLkey   tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLkitchen tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLknowledge tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLlabel tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLlanguages tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLlatency tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLlead  tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLleads tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLlevel tp: 1 - fp: 0 - fn: 7 - tn: 1 - precision: 1.0000 - recall: 0.1250 - accuracy: 0.1250 - f1-score: 0.2222
# SKILLlevels tp: 10 - fp: 0 - fn: 0 - tn: 10 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - f1-score: 1.0000
# SKILLlist  tp: 0 - fp: 0 - fn: 10 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLlocation tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLmachine tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLmaintenance tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLmaking tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLmanage tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLmanagement tp: 1 - fp: 15 - fn: 39 - tn: 1 - precision: 0.0625 - recall: 0.0250 - accuracy: 0.0182 - f1-score: 0.0357
# SKILLmanager tp: 37 - fp: 23 - fn: 64 - tn: 37 - precision: 0.6167 - recall: 0.3663 - accuracy: 0.2984 - f1-score: 0.4596
# SKILLmanagers tp: 2 - fp: 0 - fn: 14 - tn: 2 - precision: 1.0000 - recall: 0.1250 - accuracy: 0.1250 - f1-score: 0.2222
# SKILLmarketing tp: 1 - fp: 0 - fn: 0 - tn: 1 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - f1-score: 1.0000
# SKILLmarkets tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLmechanical tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLmedication tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLmetal tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLmitigation tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLmodelling tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLmodels tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLmotivated tp: 3 - fp: 2 - fn: 0 - tn: 3 - precision: 0.6000 - recall: 1.0000 - accuracy: 0.6000 - f1-score: 0.7500
# SKILLmotivation tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLneeds tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLnetwork tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLnetworks tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLnurse tp: 49 - fp: 11 - fn: 1 - tn: 49 - precision: 0.8167 - recall: 0.9800 - accuracy: 0.8033 - f1-score: 0.8909
# SKILLnurses tp: 6 - fp: 4 - fn: 0 - tn: 6 - precision: 0.6000 - recall: 1.0000 - accuracy: 0.6000 - f1-score: 0.7500
# SKILLnursing tp: 2 - fp: 1 - fn: 13 - tn: 2 - precision: 0.6667 - recall: 0.1333 - accuracy: 0.1250 - f1-score: 0.2222
# SKILLoffice tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLopenview tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLoperates tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLoperations tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLoperative tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLoperatives tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLoptimization tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLorder tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLorientation tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLoriented tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLpartner tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLpatient tp: 4 - fp: 0 - fn: 0 - tn: 4 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - f1-score: 1.0000
# SKILLpatients tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLpatterns tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLpeople tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLpersonality tp: 0 - fp: 0 - fn: 5 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLplan  tp: 0 - fp: 0 - fn: 5 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLplanning tp: 1 - fp: 7 - fn: 13 - tn: 1 - precision: 0.1250 - recall: 0.0714 - accuracy: 0.0476 - f1-score: 0.0909
# SKILLplans tp: 9 - fp: 10 - fn: 7 - tn: 9 - precision: 0.4737 - recall: 0.5625 - accuracy: 0.3462 - f1-score: 0.5143
# SKILLplatform tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLpower tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLpowershape tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLpractice tp: 5 - fp: 4 - fn: 2 - tn: 5 - precision: 0.5556 - recall: 0.7143 - accuracy: 0.4545 - f1-score: 0.6250
# SKILLpractices tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLpractitioner tp: 8 - fp: 3 - fn: 0 - tn: 8 - precision: 0.7273 - recall: 1.0000 - accuracy: 0.7273 - f1-score: 0.8421
# SKILLprecision tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLpressure tp: 0 - fp: 1 - fn: 0 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLproblem tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLprocedures tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLprocess tp: 22 - fp: 1 - fn: 3 - tn: 22 - precision: 0.9565 - recall: 0.8800 - accuracy: 0.8462 - f1-score: 0.9167
# SKILLprocesses tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLproduction tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLproducts tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLprofessionals tp: 2 - fp: 0 - fn: 2 - tn: 2 - precision: 1.0000 - recall: 0.5000 - accuracy: 0.5000 - f1-score: 0.6667
# SKILLprograms tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLprogress tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLprotection tp: 1 - fp: 0 - fn: 0 - tn: 1 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - f1-score: 1.0000
# SKILLprovided tp: 0 - fp: 0 - fn: 4 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLprovider tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLprovides tp: 1 - fp: 0 - fn: 0 - tn: 1 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - f1-score: 1.0000
# SKILLrac   tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLrate  tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLrecovery tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLrecruitment tp: 24 - fp: 7 - fn: 2 - tn: 24 - precision: 0.7742 - recall: 0.9231 - accuracy: 0.7273 - f1-score: 0.8421
# SKILLreflection tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLregistered tp: 1 - fp: 0 - fn: 4 - tn: 1 - precision: 1.0000 - recall: 0.2000 - accuracy: 0.2000 - f1-score: 0.3333
# SKILLrelationships tp: 2 - fp: 0 - fn: 5 - tn: 2 - precision: 1.0000 - recall: 0.2857 - accuracy: 0.2857 - f1-score: 0.4444
# SKILLrequired tp: 0 - fp: 0 - fn: 7 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLrequirements tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLresearch tp: 0 - fp: 2 - fn: 0 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLreview tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLrooms tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLsafety tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLsalary tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLsales tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLsatisfaction tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLsavvy tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLscience tp: 0 - fp: 0 - fn: 8 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLscripting tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLsecurity tp: 0 - fp: 0 - fn: 5 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLserver tp: 0 - fp: 0 - fn: 4 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLservice tp: 34 - fp: 23 - fn: 11 - tn: 34 - precision: 0.5965 - recall: 0.7556 - accuracy: 0.5000 - f1-score: 0.6667
# SKILLservices tp: 6 - fp: 2 - fn: 29 - tn: 6 - precision: 0.7500 - recall: 0.1714 - accuracy: 0.1622 - f1-score: 0.2790
# SKILLservicing tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLset   tp: 0 - fp: 0 - fn: 5 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLsharepoint tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLsheet tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLsimulation tp: 0 - fp: 0 - fn: 5 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLskills tp: 38 - fp: 6 - fn: 3 - tn: 38 - precision: 0.8636 - recall: 0.9268 - accuracy: 0.8085 - f1-score: 0.8941
# SKILLsocial tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLsoftware tp: 0 - fp: 0 - fn: 5 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLsolution tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLsolutions tp: 1 - fp: 1 - fn: 0 - tn: 1 - precision: 0.5000 - recall: 1.0000 - accuracy: 0.5000 - f1-score: 0.6667
# SKILLsolve tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLspecialist tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLspecifically tp: 5 - fp: 0 - fn: 0 - tn: 5 - precision: 1.0000 - recall: 1.0000 - accuracy: 1.0000 - f1-score: 1.0000
# SKILLspecification tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLstaff tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLstore tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLstructures tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLstudio tp: 1 - fp: 1 - fn: 0 - tn: 1 - precision: 0.5000 - recall: 1.0000 - accuracy: 0.5000 - f1-score: 0.6667
# SKILLstyle tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLsupervision tp: 3 - fp: 3 - fn: 2 - tn: 3 - precision: 0.5000 - recall: 0.6000 - accuracy: 0.3750 - f1-score: 0.5455
# SKILLsupport tp: 0 - fp: 2 - fn: 14 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLsurgery tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLsystem tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLsystems tp: 0 - fp: 0 - fn: 4 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLtasks tp: 0 - fp: 0 - fn: 5 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLteam  tp: 1 - fp: 1 - fn: 10 - tn: 1 - precision: 0.5000 - recall: 0.0909 - accuracy: 0.0833 - f1-score: 0.1538
# SKILLteams tp: 0 - fp: 0 - fn: 4 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLtechnical tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLtechnology tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLterm  tp: 6 - fp: 2 - fn: 0 - tn: 6 - precision: 0.7500 - recall: 1.0000 - accuracy: 0.7500 - f1-score: 0.8571
# SKILLtest  tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLtesting tp: 0 - fp: 0 - fn: 7 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLtherapist tp: 6 - fp: 1 - fn: 0 - tn: 6 - precision: 0.8571 - recall: 1.0000 - accuracy: 0.8571 - f1-score: 0.9231
# SKILLtherapists tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLtherapy tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLtime  tp: 0 - fp: 0 - fn: 5 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLtools tp: 0 - fp: 0 - fn: 5 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLtrainers tp: 0 - fp: 0 - fn: 2 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLtraining tp: 0 - fp: 0 - fn: 4 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLtransport tp: 2 - fp: 2 - fn: 0 - tn: 2 - precision: 0.5000 - recall: 1.0000 - accuracy: 0.5000 - f1-score: 0.6667
# SKILLtreatment tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLunit  tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLunits tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLvehicle tp: 0 - fp: 0 - fn: 3 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLwork  tp: 34 - fp: 5 - fn: 8 - tn: 34 - precision: 0.8718 - recall: 0.8095 - accuracy: 0.7234 - f1-score: 0.8395
# SKILLworker tp: 24 - fp: 12 - fn: 6 - tn: 24 - precision: 0.6667 - recall: 0.8000 - accuracy: 0.5714 - f1-score: 0.7273
# SKILLworkers tp: 0 - fp: 4 - fn: 8 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLworking tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# SKILLwriting tp: 0 - fp: 0 - fn: 1 - tn: 0 - precision: 0.0000 - recall: 0.0000 - accuracy: 0.0000 - f1-score: 0.0000
# 2023-06-04 01:37:19,716 ----------------------------------------------------------------------------------------------------
# {'test_score': 0.8843,
#  'dev_score_history': [],
#  'train_loss_history': [9.41505411741169,
#   5.404614973194607,
#   4.421184256725513,
#   3.9064887288181183,
#   3.566614944395665,
#   3.2917389246263267,
#   3.1015725256908064,
#   2.9049165091961098,
#   2.790922972107102,
#   2.6592265501249805,
#   2.576242336917787,
#   2.478924518233896,
#   2.3944408998893767,
#   2.3174353961177934,
#   2.243378801922916],
#  'dev_loss_history': []}

# %% [markdown]
# ### Calculate results and and make benchmark
#
# ![image.png](attachment:image.png)
#
# As you can see the LM-LSTM-CRF is better algorithm for Job description dataset IOB format.
#
# with nice score of F1.
